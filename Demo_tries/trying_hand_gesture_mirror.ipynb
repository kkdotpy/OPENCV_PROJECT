# %%
import cv2 as cv
import mediapipe as mp
import numpy as np
import time
from threading import Thread

# %%
# Regular way of video capturing (without threading)

vs1 = cv.VideoCapture('http://192.168.0.114:4747/video')
vs2 = cv.VideoCapture('http://192.168.0.155:4747/video')

while vs1.isOpened() and vs2.isOpened():
    ret1, frame1 = vs1.read()
    ret2, frame2 = vs2.read()

    if not ret1 or not ret2:
        break

    cv.imshow('Camera 1', frame1)
    cv.imshow('Camera 2', frame2)

    if cv.waitKey(1) & 0xFF == ord('q'):
        break


vs1.release()
vs2.release()   
cv.destroyAllWindows()

# %% [markdown]
# Seems to lag a bit in one feed so threading might be better

# %%
## Threaded video capture class:

class VideoStream:
    def __init__(self, url):
        self.stream = cv.VideoCapture(url)
        self.frame = None
        self.stopped = False

    def start(self):
        Thread(target=self.update, daemon=True).start()
        return self

    def update(self):
        while not self.stopped:
            if self.stream.isOpened():
                ret, frame = self.stream.read()
                if ret:
                    self.frame = frame
            time.sleep(0.01)
            
    def is_Opened(self):
        return self.stream.isOpened()
    
    def read(self):
        return self.frame

    def stop(self):
        self.stopped = True
        self.stream.release()

# %%
## Video capturing from two cameras

vs1 = VideoStream('http://192.168.0.114:4747/video').start()
vs2 = VideoStream('http://192.168.0.177:4747/video').start()

# %%
#Testing the threaded video capture

while vs1.isOpened() and vs2.isOpened():
    frame1 = vs1.read()
    frame2 = vs2.read()

    cv.imshow('Camera 1', frame1)
    cv.imshow('Camera 2', frame2)

    if cv.waitKey(1) & 0xFF == ord('q'):
        break

vs1.stop()
vs2.stop()  
cv.destroyAllWindows()

# %% [markdown]
# It seems to be working a lot better now.. There's still some lag but it's almost unnoticeable

# %%
def draw_box(frame, box_color=(0, 0, 255), box_size=300):
    height, width = frame.shape[:2]
    top_left = (width // 2 - box_size // 2, height // 2 - box_size // 2)
    bottom_right = (width // 2 + box_size // 2, height // 2 + box_size // 2)
    cv.rectangle(frame, top_left, bottom_right, box_color, 2)

# %%
# Testing the box drawing function

while vs1.isOpened() and vs2.isOpened():
    frame1 = vs1.read()
    frame2 = vs2.read()
    frame2 = cv.resize(frame2, (frame1.shape[1], frame1.shape[0]))  # Resize frame2 to match frame1

    if frame1 is None or frame2 is None:
        break

    draw_box(frame1)
    draw_box(frame2)

    cv.imshow('Camera 1', frame1)
    cv.imshow('Camera 2', frame2)

    if cv.waitKey(1) & 0xFF == ord('q'):
        break

vs1.stop()
vs2.stop()  
cv.destroyAllWindows()

# %%
# Draw a red guide box
def draw_box(frame):
    h, w, _ = frame.shape
    box_w, box_h = int(w * 0.6), int(h * 0.6)
    x1, y1 = (w - box_w) // 2, (h - box_h) // 2
    x2, y2 = x1 + box_w, y1 + box_h
    cv.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)


# Bitwise AND overlay of two frames
# def bitwise_and_frames(frame1, frame2):
#     if frame1 is None or frame2 is None:
#         return None
#     if frame1.shape != frame2.shape:
#         frame2 = cv.resize(frame2, (frame1.shape[1], frame1.shape[0]))
#     return cv.bitwise_and(frame1, frame2)


# MediaPipe Setup
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2,
                       min_detection_confidence=0.5, min_tracking_confidence=0.5)
mp_draw = mp.solutions.drawing_utils

# Classify gesture based on landmarks
def classify_pose(hand_landmarks):
    thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
    index_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
    index_mcp = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP]
    middle_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
    middle_mcp = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP]

    index_extended = index_tip.y < index_mcp.y
    middle_extended = middle_tip.y < middle_mcp.y
    thumb_extended = thumb_tip.y < index_mcp.y

    if index_extended and middle_extended and not thumb_extended:
        return "VICTORY"
    elif not index_extended and not middle_extended and not thumb_extended:
        return "FIST"
    elif not index_extended and not middle_extended and thumb_extended:
        return "THUMBS_UP"
    elif index_extended and middle_extended and thumb_extended:
        return "Open"
    else:
        return "Unknown"

# Detect hands and classify gesture
def detect_and_classify(frame):
    frame_rgb = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
    results = hands.process(frame_rgb)
    pose = "Unknown"
    hand_landmarks = None
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            pose = classify_pose(hand_landmarks)
            break
    return pose, hand_landmarks

# Get edge-detected hand region
def get_edge_hand(frame, hand_landmarks):
    h, w, _ = frame.shape
    x_vals = [int(lm.x * w) for lm in hand_landmarks.landmark]
    y_vals = [int(lm.y * h) for lm in hand_landmarks.landmark]
    x_min, x_max = min(x_vals), max(x_vals)
    y_min, y_max = min(y_vals), max(y_vals)
    margin = 30
    x_min = max(0, x_min - margin)
    y_min = max(0, y_min - margin)
    x_max = min(w, x_max + margin)
    y_max = min(h, y_max + margin)

    hand_crop = frame[y_min:y_max, x_min:x_max]
    gray = cv.cvtColor(hand_crop, cv.COLOR_BGR2GRAY)
    edges = cv.Canny(gray, 100, 200)
    edges_bgr = cv.cvtColor(edges, cv.COLOR_GRAY2BGR)
    resized = cv.resize(edges_bgr, (300, 300))
    return resized

# Main Loop
while True:
    frame1 = vs1.read()
    frame2 = vs2.read()
    frame2 = cv.resize(frame2, (frame1.shape[1], frame1.shape[0]))  # Resize frame2 to match frame1

    frame11 = frame1.copy()
    frame22 = frame2.copy()

    if frame1 is None or frame2 is None:
        continue

    draw_box(frame1)
    draw_box(frame2)

    gesture1, landmarks1 = detect_and_classify(frame1)
    gesture2, landmarks2 = detect_and_classify(frame2)

    cv.putText(frame1, f'P1: {gesture1}', (10, 60), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv.putText(frame2, f'P2: {gesture2}', (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    match_text = "MATCH!" if gesture1 == gesture2 and "Unknown" not in gesture1 else "NO MATCH"
    match_color = (0, 255, 0) if match_text == "MATCH!" else (0, 0, 255)

    # result_frame = bitwise_and_frames(frame1, frame2)
    # if result_frame is not None:
    #     cv.putText(result_frame, match_text, (10, 100), cv.FONT_HERSHEY_SIMPLEX, 1.2, match_color, 3)

    # Edge detection output
    if landmarks1:
        edge1 = get_edge_hand(frame11, landmarks1)
    else:
        edge1 = np.zeros((300, 300, 3), dtype=np.uint8)

    if landmarks2:
        edge2 = get_edge_hand(frame22, landmarks2)
    else:
        edge2 = np.zeros((300, 300, 3), dtype=np.uint8)

    combined_edge = np.hstack((edge1, edge2))
    cv.putText(combined_edge, match_text, (10, 40), cv.FONT_HERSHEY_SIMPLEX, 1.2, match_color, 3)

    # Show all windows
    cv.imshow("Player 1", frame1)
    cv.imshow("Player 2", frame2)
    # if result_frame is not None:
    #     cv.imshow("Hand Match Overlay", result_frame)
    cv.imshow("Edge Detection View", combined_edge)

    if cv.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
vs1.stop()
vs2.stop()
cv.destroyAllWindows()
# Out:
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "c:\Users\khare\Anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\khare\Anaconda3\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\khare\AppData\Local\Temp\ipykernel_42564\3824750881.py", line 16, in update
# cv2.error: Unknown C++ exception from OpenCV code

# %%
# ========== MediaPipe Setup for Gesture Detection ==========
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
hands = mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=1,
    min_detection_confidence=0.7,
    min_tracking_confidence=0.6
)

# ========== Threaded Camera Stream Class ==========
class VideoStream:
    def __init__(self, url):
        self.stream = cv.VideoCapture(url)
        self.frame = None
        self.stopped = False

    def start(self):
        Thread(target=self.update, daemon=True).start()
        return self

    def update(self):
        while not self.stopped:
            if self.stream.isOpened():
                ret, frame = self.stream.read()
                if ret:
                    self.frame = frame
            time.sleep(0.01)

    def read(self):
        return self.frame

    def stop(self):
        self.stopped = True
        self.stream.release()

# ========== Pose Classifier ==========
def classify_pose(hand_landmarks):
    thumb_tip = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP]
    index_tip = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
    index_mcp = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP]
    middle_tip = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
    middle_mcp = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP]

    index_extended = index_tip.y < index_mcp.y
    middle_extended = middle_tip.y < middle_mcp.y
    thumb_extended = thumb_tip.x < index_mcp.x

    if index_extended and middle_extended and not thumb_extended:
        return "VICTORY"
    elif not index_extended and not middle_extended:
        return "FIST"
    elif index_extended and not middle_extended and thumb_extended:
        return "THUMBS_UP"
    else:
        return "OPEN"

# ========== Start the Two Streams ==========
vs1 = VideoStream('http://192.168.0.177:4747/video').start()
vs2 = VideoStream('http://192.168.0.155:4747/video').start()

# ========== Create Display Windows ==========
cv.namedWindow("Player 1 View", cv.WINDOW_NORMAL)
cv.namedWindow("Player 2 View", cv.WINDOW_NORMAL)
cv.namedWindow("Blended View", cv.WINDOW_NORMAL)
cv.resizeWindow("Player 1 View", 640, 480)
cv.resizeWindow("Player 2 View", 640, 480)
cv.resizeWindow("Blended View", 640, 480)

# ========== Main Loop ==========
while True:
    frame1 = vs1.read()
    frame2 = vs2.read()

    if frame1 is None or frame2 is None:
        continue

    # Match frame sizes
    if frame1.shape != frame2.shape:
        frame2 = cv.resize(frame2, (frame1.shape[1], frame1.shape[0]))

    # === Gesture Detection ===
    p1_pose, p2_pose = None, None

    results1 = hands.process(cv.cvtColor(frame1, cv.COLOR_BGR2RGB))
    if results1.multi_hand_landmarks:
        hand_landmarks = results1.multi_hand_landmarks[0]
        p1_pose = classify_pose(hand_landmarks)
        mp_drawing.draw_landmarks(frame1, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    results2 = hands.process(cv.cvtColor(frame2, cv.COLOR_BGR2RGB))
    if results2.multi_hand_landmarks:
        hand_landmarks = results2.multi_hand_landmarks[0]
        p2_pose = classify_pose(hand_landmarks)
        mp_drawing.draw_landmarks(frame2, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    # === Blended Channel View: Green from Frame1, Red from Frame2 ===
    r1, g1, b1 = cv.split(frame1)
    r2, g2, b2 = cv.split(frame2)

    # Combine: Green channel from Player 1, Red from Player 2, Blue = average
    blended = cv.merge([
        ((b1.astype(np.uint16) + b2.astype(np.uint16)) // 2).astype(np.uint8),  # Blue
        g1,  # Green from P1
        r2   # Red from P2
    ])

    # === Annotate the Blended View ===
    cv.putText(blended, f"P1 Gesture: {p1_pose or 'None'}", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,0), 2)
    cv.putText(blended, f"P2 Gesture: {p2_pose or 'None'}", (10, 60), cv.FONT_HERSHEY_SIMPLEX, 0.8, (0,0,255), 2)

    if p1_pose and p2_pose:
        match = "MATCH!" if p1_pose == p2_pose else "NO MATCH!"
        color = (0,255,0) if p1_pose == p2_pose else (0,0,255)
        cv.putText(blended, match, (10, 100), cv.FONT_HERSHEY_SIMPLEX, 1, color, 2)

    # === Display Output ===
    cv.imshow("Player 1 View", frame1)
    cv.imshow("Player 2 View", frame2)
    cv.imshow("Blended View", blended)

    if cv.waitKey(1) & 0xFF == ord('q'):
        break

# ========== Cleanup ==========
vs1.stop()
vs2.stop()
hands.close()
cv.destroyAllWindows()

# %%
cap = cv.VideoCapture(1)
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
hands = mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.7,
    min_tracking_confidence=0.6
)


while cap.isOpened():
    ret, frame = cap.read()
    if not ret: break

    frameRGB = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
    results = hands.process(frameRGB)

    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            for id, lm in enumerate(hand_landmarks.landmark):
                h, w, c = frame.shape
                cx, cy = int(lm.x * w), int(lm.y * h)
                print(f"Landmark ID: {id}, Coordinates: ({cx}, {cy})")
                if id == 4:
                    cv.circle(frame, (cx, cy), 15, (255, 255, 0), -1)

            mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
        


    cv.imshow('Webcam Feed', frame)
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
hands.close()
cv.destroyAllWindows()
# Out:
# Landmark ID: 0, Coordinates: (171, 448)
# Landmark ID: 1, Coordinates: (238, 440)
# Landmark ID: 2, Coordinates: (299, 392)
# Landmark ID: 3, Coordinates: (336, 342)
# Landmark ID: 4, Coordinates: (370, 309)
# Landmark ID: 5, Coordinates: (258, 282)
# Landmark ID: 6, Coordinates: (283, 215)
# Landmark ID: 7, Coordinates: (295, 169)
# Landmark ID: 8, Coordinates: (301, 130)
# Landmark ID: 9, Coordinates: (219, 267)
# Landmark ID: 10, Coordinates: (237, 187)
# Landmark ID: 11, Coordinates: (246, 136)
# Landmark ID: 12, Coordinates: (251, 96)
# Landmark ID: 13, Coordinates: (177, 268)
# Landmark ID: 14, Coordinates: (191, 189)
# Landmark ID: 15, Coordinates: (198, 142)
# Landmark ID: 16, Coordinates: (202, 105)
# Landmark ID: 17, Coordinates: (131, 284)
# Landmark ID: 18, Coordinates: (118, 226)
# Landmark ID: 19, Coordinates: (109, 189)
# Landmark ID: 20, Coordinates: (101, 157)
# Landmark ID: 0, Coordinates: (167, 453)
# Landmark ID: 1, Coordinates: (236, 440)
# Landmark ID: 2, Coordinates: (300, 390)
# Landmark ID: 3, Coordinates: (340, 337)
# Landmark ID: 4, Coordinates: (376, 302)
# Landmark ID: 5, Coordinates: (256, 278)
# Landmark ID: 6, Coordinates: (284, 209)
# Landmark ID: 7, Coordinates: (295, 164)
# Landmark ID: 8, Coordinates: (301, 127)
# Landmark ID: 9, Coordinates: (217, 262)
# Landmark ID: 10, Coordinates: (238, 181)
# Landmark ID: 11, Coordinates: (246, 131)
# Landmark ID: 12, Coordinates: (250, 91)
# Landmark ID: 13, Coordinates: (177, 263)
# Landmark ID: 14, Coordinates: (191, 185)
# Landmark ID: 15, Coordinates: (197, 139)
# Landmark ID: 16, Coordinates: (200, 104)
# Landmark ID: 17, Coordinates: (133, 280)
# Landmark ID: 18, Coordinates: (120, 224)
# Landmark ID: 19, Coordinates: (110, 186)
# Landmark ID: 20, Coordinates: (102, 154)
# Landmark ID: 0, Coordinates: (168, 451)
# Landmark ID: 1, Coordinates: (235, 434)
# Landmark ID: 2, Coordinates: (298, 385)
# Landmark ID: 3, Coordinates: (338, 333)
# Landmark ID: 4, Coordinates: (371, 296)
# Landmark ID: 5, Coordinates: (256, 272)
# Landmark ID: 6, Coordinates: (284, 203)
# Landmark ID: 7, Coordinates: (293, 160)
# Landmark ID: 8, Coordinates: (298, 124)
# Landmark ID: 9, Coordinates: (217, 257)
# Landmark ID: 10, Coordinates: (237, 178)
# Landmark ID: 11, Coordinates: (244, 128)
# Landmark ID: 12, Coordinates: (247, 90)
# Landmark ID: 13, Coordinates: (177, 259)
# Landmark ID: 14, Coordinates: (191, 182)
# Landmark ID: 15, Coordinates: (197, 137)
# Landmark ID: 16, Coordinates: (200, 102)
# Landmark ID: 17, Coordinates: (134, 276)
# Landmark ID: 18, Coordinates: (120, 221)
# Landmark ID: 19, Coordinates: (110, 184)
# Landmark ID: 20, Coordinates: (102, 152)
# Landmark ID: 0, Coordinates: (167, 442)
# Landmark ID: 1, Coordinates: (235, 424)
# Landmark ID: 2, Coordinates: (300, 374)
# Landmark ID: 3, Coordinates: (339, 321)
# Landmark ID: 4, Coordinates: (372, 284)
# Landmark ID: 5, Coordinates: (258, 266)
# Landmark ID: 6, Coordinates: (285, 196)
# Landmark ID: 7, Coordinates: (293, 153)
# Landmark ID: 8, Coordinates: (295, 116)
# Landmark ID: 9, Coordinates: (218, 251)
# Landmark ID: 10, Coordinates: (236, 171)
# Landmark ID: 11, Coordinates: (242, 122)
# Landmark ID: 12, Coordinates: (243, 84)
# Landmark ID: 13, Coordinates: (178, 254)
# Landmark ID: 14, Coordinates: (190, 177)
# Landmark ID: 15, Coordinates: (195, 133)
# Landmark ID: 16, Coordinates: (198, 98)
# Landmark ID: 17, Coordinates: (135, 271)
# Landmark ID: 18, Coordinates: (121, 217)
# Landmark ID: 19, Coordinates: (110, 181)
# Landmark ID: 20, Coordinates: (102, 149)
# Landmark ID: 0, Coordinates: (182, 413)
# Landmark ID: 1, Coordinates: (249, 392)
# Landmark ID: 2, Coordinates: (311, 346)
# Landmark ID: 3, Coordinates: (351, 299)
# Landmark ID: 4, Coordinates: (384, 265)
# Landmark ID: 5, Coordinates: (268, 242)
# Landmark ID: 6, Coordinates: (295, 177)
# Landmark ID: 7, Coordinates: (305, 135)
# Landmark ID: 8, Coordinates: (310, 100)
# Landmark ID: 9, Coordinates: (230, 229)
# Landmark ID: 10, Coordinates: (250, 151)
# Landmark ID: 11, Coordinates: (258, 103)
# Landmark ID: 12, Coordinates: (261, 65)
# Landmark ID: 13, Coordinates: (191, 231)
# Landmark ID: 14, Coordinates: (207, 153)
# Landmark ID: 15, Coordinates: (213, 108)
# Landmark ID: 16, Coordinates: (218, 72)
# Landmark ID: 17, Coordinates: (149, 246)
# Landmark ID: 18, Coordinates: (138, 191)
# Landmark ID: 19, Coordinates: (129, 156)
# Landmark ID: 20, Coordinates: (122, 125)
# Landmark ID: 0, Coordinates: (189, 405)
# Landmark ID: 1, Coordinates: (257, 386)
# Landmark ID: 2, Coordinates: (318, 341)
# Landmark ID: 3, Coordinates: (356, 292)
# Landmark ID: 4, Coordinates: (387, 255)
# Landmark ID: 5, Coordinates: (273, 237)
# Landmark ID: 6, Coordinates: (300, 170)
# Landmark ID: 7, Coordinates: (311, 127)
# Landmark ID: 8, Coordinates: (317, 91)
# Landmark ID: 9, Coordinates: (234, 224)
# Landmark ID: 10, Coordinates: (254, 148)
# Landmark ID: 11, Coordinates: (261, 99)
# Landmark ID: 12, Coordinates: (263, 61)
# Landmark ID: 13, Coordinates: (194, 227)
# Landmark ID: 14, Coordinates: (208, 152)
# Landmark ID: 15, Coordinates: (214, 107)
# Landmark ID: 16, Coordinates: (218, 72)
# Landmark ID: 17, Coordinates: (153, 243)
# Landmark ID: 18, Coordinates: (140, 191)
# Landmark ID: 19, Coordinates: (130, 154)
# Landmark ID: 20, Coordinates: (124, 123)
# Landmark ID: 0, Coordinates: (191, 404)
# Landmark ID: 1, Coordinates: (259, 388)
# Landmark ID: 2, Coordinates: (320, 341)
# Landmark ID: 3, Coordinates: (361, 292)
# Landmark ID: 4, Coordinates: (396, 256)
# Landmark ID: 5, Coordinates: (276, 235)
# Landmark ID: 6, Coordinates: (304, 170)
# Landmark ID: 7, Coordinates: (315, 127)
# Landmark ID: 8, Coordinates: (321, 90)
# Landmark ID: 9, Coordinates: (238, 221)
# Landmark ID: 10, Coordinates: (257, 145)
# Landmark ID: 11, Coordinates: (264, 95)
# Landmark ID: 12, Coordinates: (267, 55)
# Landmark ID: 13, Coordinates: (198, 224)
# Landmark ID: 14, Coordinates: (212, 148)
# Landmark ID: 15, Coordinates: (217, 101)
# Landmark ID: 16, Coordinates: (221, 63)
# Landmark ID: 17, Coordinates: (155, 241)
# Landmark ID: 18, Coordinates: (142, 188)
# Landmark ID: 19, Coordinates: (132, 151)
# Landmark ID: 20, Coordinates: (125, 119)
# Landmark ID: 0, Coordinates: (210, 416)
# Landmark ID: 1, Coordinates: (281, 400)
# Landmark ID: 2, Coordinates: (343, 353)
# Landmark ID: 3, Coordinates: (381, 303)
# Landmark ID: 4, Coordinates: (414, 267)
# Landmark ID: 5, Coordinates: (299, 244)
# Landmark ID: 6, Coordinates: (324, 176)
# Landmark ID: 7, Coordinates: (335, 132)
# Landmark ID: 8, Coordinates: (341, 96)
# Landmark ID: 9, Coordinates: (260, 230)
# Landmark ID: 10, Coordinates: (277, 149)
# Landmark ID: 11, Coordinates: (284, 97)
# Landmark ID: 12, Coordinates: (286, 55)
# Landmark ID: 13, Coordinates: (219, 233)
# Landmark ID: 14, Coordinates: (231, 154)
# Landmark ID: 15, Coordinates: (234, 106)
# Landmark ID: 16, Coordinates: (237, 67)
# Landmark ID: 17, Coordinates: (175, 252)
# Landmark ID: 18, Coordinates: (159, 197)
# Landmark ID: 19, Coordinates: (148, 160)
# Landmark ID: 20, Coordinates: (140, 127)
# Landmark ID: 0, Coordinates: (231, 383)
# Landmark ID: 1, Coordinates: (290, 380)
# Landmark ID: 2, Coordinates: (346, 337)
# Landmark ID: 3, Coordinates: (387, 297)
# Landmark ID: 4, Coordinates: (423, 268)
# Landmark ID: 5, Coordinates: (313, 246)
# Landmark ID: 6, Coordinates: (334, 183)
# Landmark ID: 7, Coordinates: (346, 138)
# Landmark ID: 8, Coordinates: (352, 102)
# Landmark ID: 9, Coordinates: (270, 232)
# Landmark ID: 10, Coordinates: (284, 153)
# Landmark ID: 11, Coordinates: (292, 103)
# Landmark ID: 12, Coordinates: (296, 64)
# Landmark ID: 13, Coordinates: (228, 236)
# Landmark ID: 14, Coordinates: (239, 166)
# Landmark ID: 15, Coordinates: (242, 116)
# Landmark ID: 16, Coordinates: (243, 76)
# Landmark ID: 17, Coordinates: (186, 257)
# Landmark ID: 18, Coordinates: (174, 205)
# Landmark ID: 19, Coordinates: (164, 169)
# Landmark ID: 20, Coordinates: (155, 135)
# Landmark ID: 0, Coordinates: (218, 423)
# Landmark ID: 1, Coordinates: (286, 405)
# Landmark ID: 2, Coordinates: (348, 355)
# Landmark ID: 3, Coordinates: (391, 307)
# Landmark ID: 4, Coordinates: (428, 272)
# Landmark ID: 5, Coordinates: (308, 246)
# Landmark ID: 6, Coordinates: (336, 177)
# Landmark ID: 7, Coordinates: (348, 134)
# Landmark ID: 8, Coordinates: (355, 97)
# Landmark ID: 9, Coordinates: (268, 231)
# Landmark ID: 10, Coordinates: (287, 150)
# Landmark ID: 11, Coordinates: (295, 98)
# Landmark ID: 12, Coordinates: (297, 56)
# Landmark ID: 13, Coordinates: (227, 235)
# Landmark ID: 14, Coordinates: (240, 157)
# Landmark ID: 15, Coordinates: (244, 109)
# Landmark ID: 16, Coordinates: (247, 71)
# Landmark ID: 17, Coordinates: (184, 254)
# Landmark ID: 18, Coordinates: (169, 199)
# Landmark ID: 19, Coordinates: (158, 162)
# Landmark ID: 20, Coordinates: (151, 129)
# Landmark ID: 0, Coordinates: (222, 425)
# Landmark ID: 1, Coordinates: (293, 408)
# Landmark ID: 2, Coordinates: (358, 359)
# Landmark ID: 3, Coordinates: (400, 309)
# Landmark ID: 4, Coordinates: (437, 273)
# Landmark ID: 5, Coordinates: (317, 247)
# Landmark ID: 6, Coordinates: (347, 178)
# Landmark ID: 7, Coordinates: (359, 134)
# Landmark ID: 8, Coordinates: (366, 97)
# Landmark ID: 9, Coordinates: (278, 233)
# Landmark ID: 10, Coordinates: (296, 152)
# Landmark ID: 11, Coordinates: (304, 101)
# Landmark ID: 12, Coordinates: (307, 58)
# Landmark ID: 13, Coordinates: (237, 237)
# Landmark ID: 14, Coordinates: (250, 158)
# Landmark ID: 15, Coordinates: (254, 111)
# Landmark ID: 16, Coordinates: (256, 72)
# Landmark ID: 17, Coordinates: (195, 256)
# Landmark ID: 18, Coordinates: (178, 201)
# Landmark ID: 19, Coordinates: (168, 164)
# Landmark ID: 20, Coordinates: (161, 130)
# Landmark ID: 0, Coordinates: (231, 423)
# Landmark ID: 1, Coordinates: (301, 406)
# Landmark ID: 2, Coordinates: (367, 358)
# Landmark ID: 3, Coordinates: (406, 308)
# Landmark ID: 4, Coordinates: (443, 272)
# Landmark ID: 5, Coordinates: (325, 249)
# Landmark ID: 6, Coordinates: (355, 180)
# Landmark ID: 7, Coordinates: (368, 137)
# Landmark ID: 8, Coordinates: (375, 101)
# Landmark ID: 9, Coordinates: (286, 233)
# Landmark ID: 10, Coordinates: (306, 153)
# Landmark ID: 11, Coordinates: (314, 102)
# Landmark ID: 12, Coordinates: (317, 61)
# Landmark ID: 13, Coordinates: (246, 235)
# Landmark ID: 14, Coordinates: (260, 157)
# Landmark ID: 15, Coordinates: (264, 111)
# Landmark ID: 16, Coordinates: (267, 74)
# Landmark ID: 17, Coordinates: (204, 252)
# Landmark ID: 18, Coordinates: (187, 198)
# Landmark ID: 19, Coordinates: (178, 162)
# Landmark ID: 20, Coordinates: (171, 130)
# Landmark ID: 0, Coordinates: (259, 411)
# Landmark ID: 1, Coordinates: (328, 390)
# Landmark ID: 2, Coordinates: (389, 343)
# Landmark ID: 3, Coordinates: (426, 296)
# Landmark ID: 4, Coordinates: (463, 261)
# Landmark ID: 5, Coordinates: (347, 239)
# Landmark ID: 6, Coordinates: (379, 174)
# Landmark ID: 7, Coordinates: (394, 132)
# Landmark ID: 8, Coordinates: (404, 98)
# Landmark ID: 9, Coordinates: (310, 225)
# Landmark ID: 10, Coordinates: (331, 146)
# Landmark ID: 11, Coordinates: (343, 96)
# Landmark ID: 12, Coordinates: (352, 57)
# Landmark ID: 13, Coordinates: (272, 226)
# Landmark ID: 14, Coordinates: (283, 149)
# Landmark ID: 15, Coordinates: (291, 104)
# Landmark ID: 16, Coordinates: (299, 68)
# Landmark ID: 17, Coordinates: (232, 243)
# Landmark ID: 18, Coordinates: (218, 189)
# Landmark ID: 19, Coordinates: (209, 153)
# Landmark ID: 20, Coordinates: (204, 121)
# Landmark ID: 0, Coordinates: (266, 405)
# Landmark ID: 1, Coordinates: (334, 385)
# Landmark ID: 2, Coordinates: (395, 341)
# Landmark ID: 3, Coordinates: (436, 296)
# Landmark ID: 4, Coordinates: (474, 259)
# Landmark ID: 5, Coordinates: (350, 236)
# Landmark ID: 6, Coordinates: (384, 172)
# Landmark ID: 7, Coordinates: (399, 130)
# Landmark ID: 8, Coordinates: (409, 95)
# Landmark ID: 9, Coordinates: (314, 220)
# Landmark ID: 10, Coordinates: (336, 142)
# Landmark ID: 11, Coordinates: (348, 93)
# Landmark ID: 12, Coordinates: (355, 54)
# Landmark ID: 13, Coordinates: (277, 221)
# Landmark ID: 14, Coordinates: (290, 145)
# Landmark ID: 15, Coordinates: (297, 100)
# Landmark ID: 16, Coordinates: (303, 65)
# Landmark ID: 17, Coordinates: (240, 237)
# Landmark ID: 18, Coordinates: (225, 186)
# Landmark ID: 19, Coordinates: (217, 149)
# Landmark ID: 20, Coordinates: (212, 117)
# Landmark ID: 0, Coordinates: (275, 403)
# Landmark ID: 1, Coordinates: (343, 384)
# Landmark ID: 2, Coordinates: (403, 340)
# Landmark ID: 3, Coordinates: (441, 293)
# Landmark ID: 4, Coordinates: (478, 259)
# Landmark ID: 5, Coordinates: (359, 234)
# Landmark ID: 6, Coordinates: (392, 170)
# Landmark ID: 7, Coordinates: (407, 129)
# Landmark ID: 8, Coordinates: (416, 94)
# Landmark ID: 9, Coordinates: (322, 218)
# Landmark ID: 10, Coordinates: (344, 142)
# Landmark ID: 11, Coordinates: (356, 92)
# Landmark ID: 12, Coordinates: (364, 52)
# Landmark ID: 13, Coordinates: (286, 219)
# Landmark ID: 14, Coordinates: (298, 143)
# Landmark ID: 15, Coordinates: (305, 97)
# Landmark ID: 16, Coordinates: (313, 61)
# Landmark ID: 17, Coordinates: (249, 235)
# Landmark ID: 18, Coordinates: (234, 184)
# Landmark ID: 19, Coordinates: (225, 147)
# Landmark ID: 20, Coordinates: (220, 116)
# Landmark ID: 0, Coordinates: (283, 400)
# Landmark ID: 1, Coordinates: (350, 382)
# Landmark ID: 2, Coordinates: (410, 339)
# Landmark ID: 3, Coordinates: (448, 294)
# Landmark ID: 4, Coordinates: (487, 261)
# Landmark ID: 5, Coordinates: (366, 233)
# Landmark ID: 6, Coordinates: (399, 170)
# Landmark ID: 7, Coordinates: (415, 128)
# Landmark ID: 8, Coordinates: (425, 94)
# Landmark ID: 9, Coordinates: (330, 217)
# Landmark ID: 10, Coordinates: (352, 142)
# Landmark ID: 11, Coordinates: (364, 92)
# Landmark ID: 12, Coordinates: (372, 54)
# Landmark ID: 13, Coordinates: (293, 217)
# Landmark ID: 14, Coordinates: (305, 142)
# Landmark ID: 15, Coordinates: (312, 97)
# Landmark ID: 16, Coordinates: (320, 62)
# Landmark ID: 17, Coordinates: (256, 232)
# Landmark ID: 18, Coordinates: (240, 179)
# Landmark ID: 19, Coordinates: (233, 141)
# Landmark ID: 20, Coordinates: (231, 109)
# Landmark ID: 0, Coordinates: (305, 397)
# Landmark ID: 1, Coordinates: (375, 384)
# Landmark ID: 2, Coordinates: (435, 344)
# Landmark ID: 3, Coordinates: (472, 301)
# Landmark ID: 4, Coordinates: (505, 264)
# Landmark ID: 5, Coordinates: (391, 232)
# Landmark ID: 6, Coordinates: (426, 166)
# Landmark ID: 7, Coordinates: (442, 125)
# Landmark ID: 8, Coordinates: (455, 91)
# Landmark ID: 9, Coordinates: (355, 216)
# Landmark ID: 10, Coordinates: (378, 138)
# Landmark ID: 11, Coordinates: (391, 88)
# Landmark ID: 12, Coordinates: (401, 50)
# Landmark ID: 13, Coordinates: (319, 216)
# Landmark ID: 14, Coordinates: (330, 142)
# Landmark ID: 15, Coordinates: (340, 97)
# Landmark ID: 16, Coordinates: (349, 62)
# Landmark ID: 17, Coordinates: (281, 231)
# Landmark ID: 18, Coordinates: (268, 178)
# Landmark ID: 19, Coordinates: (261, 141)
# Landmark ID: 20, Coordinates: (257, 109)
# Landmark ID: 0, Coordinates: (315, 397)
# Landmark ID: 1, Coordinates: (382, 381)
# Landmark ID: 2, Coordinates: (440, 341)
# Landmark ID: 3, Coordinates: (478, 299)
# Landmark ID: 4, Coordinates: (513, 266)
# Landmark ID: 5, Coordinates: (397, 227)
# Landmark ID: 6, Coordinates: (428, 164)
# Landmark ID: 7, Coordinates: (444, 124)
# Landmark ID: 8, Coordinates: (456, 92)
# Landmark ID: 9, Coordinates: (361, 212)
# Landmark ID: 10, Coordinates: (383, 138)
# Landmark ID: 11, Coordinates: (395, 89)
# Landmark ID: 12, Coordinates: (404, 50)
# Landmark ID: 13, Coordinates: (325, 214)
# Landmark ID: 14, Coordinates: (337, 140)
# Landmark ID: 15, Coordinates: (345, 95)
# Landmark ID: 16, Coordinates: (353, 59)
# Landmark ID: 17, Coordinates: (287, 230)
# Landmark ID: 18, Coordinates: (274, 179)
# Landmark ID: 19, Coordinates: (267, 143)
# Landmark ID: 20, Coordinates: (264, 111)
# Landmark ID: 0, Coordinates: (316, 395)
# Landmark ID: 1, Coordinates: (384, 379)
# Landmark ID: 2, Coordinates: (441, 341)
# Landmark ID: 3, Coordinates: (479, 296)
# Landmark ID: 4, Coordinates: (514, 262)
# Landmark ID: 5, Coordinates: (398, 229)
# Landmark ID: 6, Coordinates: (431, 166)
# Landmark ID: 7, Coordinates: (448, 125)
# Landmark ID: 8, Coordinates: (460, 93)
# Landmark ID: 9, Coordinates: (363, 214)
# Landmark ID: 10, Coordinates: (387, 140)
# Landmark ID: 11, Coordinates: (399, 91)
# Landmark ID: 12, Coordinates: (409, 53)
# Landmark ID: 13, Coordinates: (327, 214)
# Landmark ID: 14, Coordinates: (342, 139)
# Landmark ID: 15, Coordinates: (351, 94)
# Landmark ID: 16, Coordinates: (360, 59)
# Landmark ID: 17, Coordinates: (289, 227)
# Landmark ID: 18, Coordinates: (278, 176)
# Landmark ID: 19, Coordinates: (272, 139)
# Landmark ID: 20, Coordinates: (269, 109)
# Landmark ID: 0, Coordinates: (304, 393)
# Landmark ID: 1, Coordinates: (373, 378)
# Landmark ID: 2, Coordinates: (434, 340)
# Landmark ID: 3, Coordinates: (473, 295)
# Landmark ID: 4, Coordinates: (509, 260)
# Landmark ID: 5, Coordinates: (393, 231)
# Landmark ID: 6, Coordinates: (424, 166)
# Landmark ID: 7, Coordinates: (440, 125)
# Landmark ID: 8, Coordinates: (452, 92)
# Landmark ID: 9, Coordinates: (356, 215)
# Landmark ID: 10, Coordinates: (377, 140)
# Landmark ID: 11, Coordinates: (389, 90)
# Landmark ID: 12, Coordinates: (399, 52)
# Landmark ID: 13, Coordinates: (319, 215)
# Landmark ID: 14, Coordinates: (331, 143)
# Landmark ID: 15, Coordinates: (339, 98)
# Landmark ID: 16, Coordinates: (348, 64)
# Landmark ID: 17, Coordinates: (280, 228)
# Landmark ID: 18, Coordinates: (269, 177)
# Landmark ID: 19, Coordinates: (264, 141)
# Landmark ID: 20, Coordinates: (262, 111)
# Landmark ID: 0, Coordinates: (293, 392)
# Landmark ID: 1, Coordinates: (365, 377)
# Landmark ID: 2, Coordinates: (426, 337)
# Landmark ID: 3, Coordinates: (463, 292)
# Landmark ID: 4, Coordinates: (500, 258)
# Landmark ID: 5, Coordinates: (383, 232)
# Landmark ID: 6, Coordinates: (417, 168)
# Landmark ID: 7, Coordinates: (433, 128)
# Landmark ID: 8, Coordinates: (447, 94)
# Landmark ID: 9, Coordinates: (346, 215)
# Landmark ID: 10, Coordinates: (367, 138)
# Landmark ID: 11, Coordinates: (379, 89)
# Landmark ID: 12, Coordinates: (389, 52)
# Landmark ID: 13, Coordinates: (308, 215)
# Landmark ID: 14, Coordinates: (322, 141)
# Landmark ID: 15, Coordinates: (330, 97)
# Landmark ID: 16, Coordinates: (340, 63)
# Landmark ID: 17, Coordinates: (270, 228)
# Landmark ID: 18, Coordinates: (259, 177)
# Landmark ID: 19, Coordinates: (254, 142)
# Landmark ID: 20, Coordinates: (253, 112)
# Landmark ID: 0, Coordinates: (277, 368)
# Landmark ID: 1, Coordinates: (338, 364)
# Landmark ID: 2, Coordinates: (403, 334)
# Landmark ID: 3, Coordinates: (450, 301)
# Landmark ID: 4, Coordinates: (476, 267)
# Landmark ID: 5, Coordinates: (376, 242)
# Landmark ID: 6, Coordinates: (397, 174)
# Landmark ID: 7, Coordinates: (409, 126)
# Landmark ID: 8, Coordinates: (419, 88)
# Landmark ID: 9, Coordinates: (342, 226)
# Landmark ID: 10, Coordinates: (351, 162)
# Landmark ID: 11, Coordinates: (357, 128)
# Landmark ID: 12, Coordinates: (359, 103)
# Landmark ID: 13, Coordinates: (302, 228)
# Landmark ID: 14, Coordinates: (307, 161)
# Landmark ID: 15, Coordinates: (308, 115)
# Landmark ID: 16, Coordinates: (310, 81)
# Landmark ID: 17, Coordinates: (260, 242)
# Landmark ID: 18, Coordinates: (252, 194)
# Landmark ID: 19, Coordinates: (247, 160)
# Landmark ID: 20, Coordinates: (245, 131)
# Landmark ID: 0, Coordinates: (283, 391)
# Landmark ID: 1, Coordinates: (352, 376)
# Landmark ID: 2, Coordinates: (413, 333)
# Landmark ID: 3, Coordinates: (452, 288)
# Landmark ID: 4, Coordinates: (490, 256)
# Landmark ID: 5, Coordinates: (372, 233)
# Landmark ID: 6, Coordinates: (406, 168)
# Landmark ID: 7, Coordinates: (421, 126)
# Landmark ID: 8, Coordinates: (433, 92)
# Landmark ID: 9, Coordinates: (333, 216)
# Landmark ID: 10, Coordinates: (357, 140)
# Landmark ID: 11, Coordinates: (368, 90)
# Landmark ID: 12, Coordinates: (377, 52)
# Landmark ID: 13, Coordinates: (295, 215)
# Landmark ID: 14, Coordinates: (309, 142)
# Landmark ID: 15, Coordinates: (318, 98)
# Landmark ID: 16, Coordinates: (328, 65)
# Landmark ID: 17, Coordinates: (257, 228)
# Landmark ID: 18, Coordinates: (244, 176)
# Landmark ID: 19, Coordinates: (239, 139)
# Landmark ID: 20, Coordinates: (237, 109)
# Landmark ID: 0, Coordinates: (228, 401)
# Landmark ID: 1, Coordinates: (300, 380)
# Landmark ID: 2, Coordinates: (361, 327)
# Landmark ID: 3, Coordinates: (397, 279)
# Landmark ID: 4, Coordinates: (432, 253)
# Landmark ID: 5, Coordinates: (319, 230)
# Landmark ID: 6, Coordinates: (346, 164)
# Landmark ID: 7, Coordinates: (360, 121)
# Landmark ID: 8, Coordinates: (368, 85)
# Landmark ID: 9, Coordinates: (280, 217)
# Landmark ID: 10, Coordinates: (296, 140)
# Landmark ID: 11, Coordinates: (305, 90)
# Landmark ID: 12, Coordinates: (310, 50)
# Landmark ID: 13, Coordinates: (241, 219)
# Landmark ID: 14, Coordinates: (251, 144)
# Landmark ID: 15, Coordinates: (257, 98)
# Landmark ID: 16, Coordinates: (261, 62)
# Landmark ID: 17, Coordinates: (199, 237)
# Landmark ID: 18, Coordinates: (183, 185)
# Landmark ID: 19, Coordinates: (174, 150)
# Landmark ID: 20, Coordinates: (169, 119)
# Landmark ID: 0, Coordinates: (214, 400)
# Landmark ID: 1, Coordinates: (282, 378)
# Landmark ID: 2, Coordinates: (343, 329)
# Landmark ID: 3, Coordinates: (379, 281)
# Landmark ID: 4, Coordinates: (412, 248)
# Landmark ID: 5, Coordinates: (303, 228)
# Landmark ID: 6, Coordinates: (331, 163)
# Landmark ID: 7, Coordinates: (345, 120)
# Landmark ID: 8, Coordinates: (355, 85)
# Landmark ID: 9, Coordinates: (263, 215)
# Landmark ID: 10, Coordinates: (281, 137)
# Landmark ID: 11, Coordinates: (289, 88)
# Landmark ID: 12, Coordinates: (294, 49)
# Landmark ID: 13, Coordinates: (224, 218)
# Landmark ID: 14, Coordinates: (238, 144)
# Landmark ID: 15, Coordinates: (243, 98)
# Landmark ID: 16, Coordinates: (246, 63)
# Landmark ID: 17, Coordinates: (182, 237)
# Landmark ID: 18, Coordinates: (168, 186)
# Landmark ID: 19, Coordinates: (157, 151)
# Landmark ID: 20, Coordinates: (148, 122)
# Landmark ID: 0, Coordinates: (204, 402)
# Landmark ID: 1, Coordinates: (271, 380)
# Landmark ID: 2, Coordinates: (331, 334)
# Landmark ID: 3, Coordinates: (364, 284)
# Landmark ID: 4, Coordinates: (395, 250)
# Landmark ID: 5, Coordinates: (287, 231)
# Landmark ID: 6, Coordinates: (316, 166)
# Landmark ID: 7, Coordinates: (330, 124)
# Landmark ID: 8, Coordinates: (339, 89)
# Landmark ID: 9, Coordinates: (248, 218)
# Landmark ID: 10, Coordinates: (268, 139)
# Landmark ID: 11, Coordinates: (274, 89)
# Landmark ID: 12, Coordinates: (276, 51)
# Landmark ID: 13, Coordinates: (209, 221)
# Landmark ID: 14, Coordinates: (223, 145)
# Landmark ID: 15, Coordinates: (226, 99)
# Landmark ID: 16, Coordinates: (229, 63)
# Landmark ID: 17, Coordinates: (168, 240)
# Landmark ID: 18, Coordinates: (153, 188)
# Landmark ID: 19, Coordinates: (142, 153)
# Landmark ID: 20, Coordinates: (133, 123)
# Landmark ID: 0, Coordinates: (189, 408)
# Landmark ID: 1, Coordinates: (256, 384)
# Landmark ID: 2, Coordinates: (317, 335)
# Landmark ID: 3, Coordinates: (353, 286)
# Landmark ID: 4, Coordinates: (383, 252)
# Landmark ID: 5, Coordinates: (274, 234)
# Landmark ID: 6, Coordinates: (302, 168)
# Landmark ID: 7, Coordinates: (316, 126)
# Landmark ID: 8, Coordinates: (326, 89)
# Landmark ID: 9, Coordinates: (235, 221)
# Landmark ID: 10, Coordinates: (254, 142)
# Landmark ID: 11, Coordinates: (260, 92)
# Landmark ID: 12, Coordinates: (264, 52)
# Landmark ID: 13, Coordinates: (196, 224)
# Landmark ID: 14, Coordinates: (209, 148)
# Landmark ID: 15, Coordinates: (214, 102)
# Landmark ID: 16, Coordinates: (219, 66)
# Landmark ID: 17, Coordinates: (154, 242)
# Landmark ID: 18, Coordinates: (139, 189)
# Landmark ID: 19, Coordinates: (128, 154)
# Landmark ID: 20, Coordinates: (118, 124)
# Landmark ID: 0, Coordinates: (184, 408)
# Landmark ID: 1, Coordinates: (247, 384)
# Landmark ID: 2, Coordinates: (307, 339)
# Landmark ID: 3, Coordinates: (343, 291)
# Landmark ID: 4, Coordinates: (370, 255)
# Landmark ID: 5, Coordinates: (262, 234)
# Landmark ID: 6, Coordinates: (293, 166)
# Landmark ID: 7, Coordinates: (306, 123)
# Landmark ID: 8, Coordinates: (314, 86)
# Landmark ID: 9, Coordinates: (222, 221)
# Landmark ID: 10, Coordinates: (239, 140)
# Landmark ID: 11, Coordinates: (246, 88)
# Landmark ID: 12, Coordinates: (250, 49)
# Landmark ID: 13, Coordinates: (183, 225)
# Landmark ID: 14, Coordinates: (194, 148)
# Landmark ID: 15, Coordinates: (199, 102)
# Landmark ID: 16, Coordinates: (203, 66)
# Landmark ID: 17, Coordinates: (142, 244)
# Landmark ID: 18, Coordinates: (126, 192)
# Landmark ID: 19, Coordinates: (115, 157)
# Landmark ID: 20, Coordinates: (105, 128)
# Landmark ID: 0, Coordinates: (178, 407)
# Landmark ID: 1, Coordinates: (240, 382)
# Landmark ID: 2, Coordinates: (299, 336)
# Landmark ID: 3, Coordinates: (334, 287)
# Landmark ID: 4, Coordinates: (362, 250)
# Landmark ID: 5, Coordinates: (252, 234)
# Landmark ID: 6, Coordinates: (280, 166)
# Landmark ID: 7, Coordinates: (292, 123)
# Landmark ID: 8, Coordinates: (298, 88)
# Landmark ID: 9, Coordinates: (213, 222)
# Landmark ID: 10, Coordinates: (229, 141)
# Landmark ID: 11, Coordinates: (233, 90)
# Landmark ID: 12, Coordinates: (234, 52)
# Landmark ID: 13, Coordinates: (174, 226)
# Landmark ID: 14, Coordinates: (184, 151)
# Landmark ID: 15, Coordinates: (188, 108)
# Landmark ID: 16, Coordinates: (191, 75)
# Landmark ID: 17, Coordinates: (132, 245)
# Landmark ID: 18, Coordinates: (115, 194)
# Landmark ID: 19, Coordinates: (104, 159)
# Landmark ID: 20, Coordinates: (94, 130)
# Landmark ID: 0, Coordinates: (165, 408)
# Landmark ID: 1, Coordinates: (228, 383)
# Landmark ID: 2, Coordinates: (287, 338)
# Landmark ID: 3, Coordinates: (324, 290)
# Landmark ID: 4, Coordinates: (354, 253)
# Landmark ID: 5, Coordinates: (241, 237)
# Landmark ID: 6, Coordinates: (270, 171)
# Landmark ID: 7, Coordinates: (282, 130)
# Landmark ID: 8, Coordinates: (290, 96)
# Landmark ID: 9, Coordinates: (201, 225)
# Landmark ID: 10, Coordinates: (217, 146)
# Landmark ID: 11, Coordinates: (221, 96)
# Landmark ID: 12, Coordinates: (223, 58)
# Landmark ID: 13, Coordinates: (163, 229)
# Landmark ID: 14, Coordinates: (173, 155)
# Landmark ID: 15, Coordinates: (176, 111)
# Landmark ID: 16, Coordinates: (179, 77)
# Landmark ID: 17, Coordinates: (122, 248)
# Landmark ID: 18, Coordinates: (106, 196)
# Landmark ID: 19, Coordinates: (94, 162)
# Landmark ID: 20, Coordinates: (84, 133)
# Landmark ID: 0, Coordinates: (132, 419)
# Landmark ID: 1, Coordinates: (195, 392)
# Landmark ID: 2, Coordinates: (254, 341)
# Landmark ID: 3, Coordinates: (289, 288)
# Landmark ID: 4, Coordinates: (323, 256)
# Landmark ID: 5, Coordinates: (206, 247)
# Landmark ID: 6, Coordinates: (232, 178)
# Landmark ID: 7, Coordinates: (241, 135)
# Landmark ID: 8, Coordinates: (245, 98)
# Landmark ID: 9, Coordinates: (167, 235)
# Landmark ID: 10, Coordinates: (182, 152)
# Landmark ID: 11, Coordinates: (187, 102)
# Landmark ID: 12, Coordinates: (187, 62)
# Landmark ID: 13, Coordinates: (130, 238)
# Landmark ID: 14, Coordinates: (138, 162)
# Landmark ID: 15, Coordinates: (140, 117)
# Landmark ID: 16, Coordinates: (140, 82)
# Landmark ID: 17, Coordinates: (91, 257)
# Landmark ID: 18, Coordinates: (75, 206)
# Landmark ID: 19, Coordinates: (63, 173)
# Landmark ID: 20, Coordinates: (52, 145)
# Landmark ID: 0, Coordinates: (116, 428)
# Landmark ID: 1, Coordinates: (179, 403)
# Landmark ID: 2, Coordinates: (237, 351)
# Landmark ID: 3, Coordinates: (270, 297)
# Landmark ID: 4, Coordinates: (305, 265)
# Landmark ID: 5, Coordinates: (188, 253)
# Landmark ID: 6, Coordinates: (216, 181)
# Landmark ID: 7, Coordinates: (228, 136)
# Landmark ID: 8, Coordinates: (237, 99)
# Landmark ID: 9, Coordinates: (150, 241)
# Landmark ID: 10, Coordinates: (164, 158)
# Landmark ID: 11, Coordinates: (168, 108)
# Landmark ID: 12, Coordinates: (169, 71)
# Landmark ID: 13, Coordinates: (113, 246)
# Landmark ID: 14, Coordinates: (120, 168)
# Landmark ID: 15, Coordinates: (122, 122)
# Landmark ID: 16, Coordinates: (122, 87)
# Landmark ID: 17, Coordinates: (73, 265)
# Landmark ID: 18, Coordinates: (56, 213)
# Landmark ID: 19, Coordinates: (43, 180)
# Landmark ID: 20, Coordinates: (31, 152)
# Landmark ID: 0, Coordinates: (114, 428)
# Landmark ID: 1, Coordinates: (177, 403)
# Landmark ID: 2, Coordinates: (234, 350)
# Landmark ID: 3, Coordinates: (267, 298)
# Landmark ID: 4, Coordinates: (302, 266)
# Landmark ID: 5, Coordinates: (186, 251)
# Landmark ID: 6, Coordinates: (215, 181)
# Landmark ID: 7, Coordinates: (227, 137)
# Landmark ID: 8, Coordinates: (234, 103)
# Landmark ID: 9, Coordinates: (148, 240)
# Landmark ID: 10, Coordinates: (163, 157)
# Landmark ID: 11, Coordinates: (166, 108)
# Landmark ID: 12, Coordinates: (165, 72)
# Landmark ID: 13, Coordinates: (112, 244)
# Landmark ID: 14, Coordinates: (121, 166)
# Landmark ID: 15, Coordinates: (123, 122)
# Landmark ID: 16, Coordinates: (122, 88)
# Landmark ID: 17, Coordinates: (74, 263)
# Landmark ID: 18, Coordinates: (56, 212)
# Landmark ID: 19, Coordinates: (44, 179)
# Landmark ID: 20, Coordinates: (33, 150)
# Landmark ID: 0, Coordinates: (534, 455)
# Landmark ID: 1, Coordinates: (463, 438)
# Landmark ID: 2, Coordinates: (405, 390)
# Landmark ID: 3, Coordinates: (367, 344)
# Landmark ID: 4, Coordinates: (336, 302)
# Landmark ID: 5, Coordinates: (448, 275)
# Landmark ID: 6, Coordinates: (429, 206)
# Landmark ID: 7, Coordinates: (416, 166)
# Landmark ID: 8, Coordinates: (407, 133)
# Landmark ID: 9, Coordinates: (492, 263)
# Landmark ID: 10, Coordinates: (483, 188)
# Landmark ID: 11, Coordinates: (472, 144)
# Landmark ID: 12, Coordinates: (463, 109)
# Landmark ID: 13, Coordinates: (534, 267)
# Landmark ID: 14, Coordinates: (533, 194)
# Landmark ID: 15, Coordinates: (527, 155)
# Landmark ID: 16, Coordinates: (519, 120)
# Landmark ID: 17, Coordinates: (576, 284)
# Landmark ID: 18, Coordinates: (587, 230)
# Landmark ID: 19, Coordinates: (588, 195)
# Landmark ID: 20, Coordinates: (587, 164)
# Landmark ID: 0, Coordinates: (83, 441)
# Landmark ID: 1, Coordinates: (145, 413)
# Landmark ID: 2, Coordinates: (203, 359)
# Landmark ID: 3, Coordinates: (234, 307)
# Landmark ID: 4, Coordinates: (265, 269)
# Landmark ID: 5, Coordinates: (149, 265)
# Landmark ID: 6, Coordinates: (176, 193)
# Landmark ID: 7, Coordinates: (186, 150)
# Landmark ID: 8, Coordinates: (190, 112)
# Landmark ID: 9, Coordinates: (111, 254)
# Landmark ID: 10, Coordinates: (126, 169)
# Landmark ID: 11, Coordinates: (129, 118)
# Landmark ID: 12, Coordinates: (127, 78)
# Landmark ID: 13, Coordinates: (75, 258)
# Landmark ID: 14, Coordinates: (82, 178)
# Landmark ID: 15, Coordinates: (83, 131)
# Landmark ID: 16, Coordinates: (82, 95)
# Landmark ID: 17, Coordinates: (36, 278)
# Landmark ID: 18, Coordinates: (17, 222)
# Landmark ID: 19, Coordinates: (4, 185)
# Landmark ID: 20, Coordinates: (-6, 155)
# Landmark ID: 0, Coordinates: (521, 450)
# Landmark ID: 1, Coordinates: (448, 437)
# Landmark ID: 2, Coordinates: (385, 392)
# Landmark ID: 3, Coordinates: (345, 346)
# Landmark ID: 4, Coordinates: (316, 302)
# Landmark ID: 5, Coordinates: (429, 274)
# Landmark ID: 6, Coordinates: (405, 206)
# Landmark ID: 7, Coordinates: (389, 167)
# Landmark ID: 8, Coordinates: (376, 136)
# Landmark ID: 9, Coordinates: (471, 260)
# Landmark ID: 10, Coordinates: (458, 181)
# Landmark ID: 11, Coordinates: (449, 133)
# Landmark ID: 12, Coordinates: (441, 96)
# Landmark ID: 13, Coordinates: (513, 264)
# Landmark ID: 14, Coordinates: (505, 192)
# Landmark ID: 15, Coordinates: (496, 153)
# Landmark ID: 16, Coordinates: (488, 119)
# Landmark ID: 17, Coordinates: (555, 282)
# Landmark ID: 18, Coordinates: (564, 227)
# Landmark ID: 19, Coordinates: (566, 191)
# Landmark ID: 20, Coordinates: (567, 158)
# Landmark ID: 0, Coordinates: (71, 438)
# Landmark ID: 1, Coordinates: (130, 408)
# Landmark ID: 2, Coordinates: (185, 356)
# Landmark ID: 3, Coordinates: (217, 304)
# Landmark ID: 4, Coordinates: (248, 265)
# Landmark ID: 5, Coordinates: (134, 258)
# Landmark ID: 6, Coordinates: (157, 187)
# Landmark ID: 7, Coordinates: (164, 144)
# Landmark ID: 8, Coordinates: (168, 108)
# Landmark ID: 9, Coordinates: (94, 248)
# Landmark ID: 10, Coordinates: (102, 167)
# Landmark ID: 11, Coordinates: (101, 118)
# Landmark ID: 12, Coordinates: (97, 80)
# Landmark ID: 13, Coordinates: (57, 256)
# Landmark ID: 14, Coordinates: (58, 179)
# Landmark ID: 15, Coordinates: (54, 134)
# Landmark ID: 16, Coordinates: (51, 99)
# Landmark ID: 17, Coordinates: (20, 279)
# Landmark ID: 18, Coordinates: (0, 231)
# Landmark ID: 19, Coordinates: (-15, 200)
# Landmark ID: 20, Coordinates: (-27, 173)
# Landmark ID: 0, Coordinates: (522, 453)
# Landmark ID: 1, Coordinates: (449, 440)
# Landmark ID: 2, Coordinates: (386, 392)
# Landmark ID: 3, Coordinates: (346, 345)
# Landmark ID: 4, Coordinates: (319, 305)
# Landmark ID: 5, Coordinates: (429, 275)
# Landmark ID: 6, Coordinates: (407, 208)
# Landmark ID: 7, Coordinates: (392, 168)
# Landmark ID: 8, Coordinates: (379, 135)
# Landmark ID: 9, Coordinates: (472, 262)
# Landmark ID: 10, Coordinates: (459, 184)
# Landmark ID: 11, Coordinates: (450, 136)
# Landmark ID: 12, Coordinates: (443, 100)
# Landmark ID: 13, Coordinates: (514, 265)
# Landmark ID: 14, Coordinates: (505, 193)
# Landmark ID: 15, Coordinates: (496, 153)
# Landmark ID: 16, Coordinates: (489, 119)
# Landmark ID: 17, Coordinates: (559, 283)
# Landmark ID: 18, Coordinates: (569, 225)
# Landmark ID: 19, Coordinates: (572, 189)
# Landmark ID: 20, Coordinates: (574, 155)
# Landmark ID: 0, Coordinates: (68, 433)
# Landmark ID: 1, Coordinates: (129, 406)
# Landmark ID: 2, Coordinates: (184, 355)
# Landmark ID: 3, Coordinates: (215, 302)
# Landmark ID: 4, Coordinates: (244, 264)
# Landmark ID: 5, Coordinates: (131, 257)
# Landmark ID: 6, Coordinates: (155, 187)
# Landmark ID: 7, Coordinates: (163, 144)
# Landmark ID: 8, Coordinates: (166, 109)
# Landmark ID: 9, Coordinates: (92, 247)
# Landmark ID: 10, Coordinates: (101, 166)
# Landmark ID: 11, Coordinates: (99, 115)
# Landmark ID: 12, Coordinates: (94, 78)
# Landmark ID: 13, Coordinates: (57, 256)
# Landmark ID: 14, Coordinates: (60, 180)
# Landmark ID: 15, Coordinates: (57, 135)
# Landmark ID: 16, Coordinates: (53, 99)
# Landmark ID: 17, Coordinates: (23, 280)
# Landmark ID: 18, Coordinates: (1, 235)
# Landmark ID: 19, Coordinates: (-14, 204)
# Landmark ID: 20, Coordinates: (-27, 178)
# Landmark ID: 0, Coordinates: (495, 449)
# Landmark ID: 1, Coordinates: (420, 436)
# Landmark ID: 2, Coordinates: (355, 389)
# Landmark ID: 3, Coordinates: (316, 343)
# Landmark ID: 4, Coordinates: (287, 303)
# Landmark ID: 5, Coordinates: (397, 272)
# Landmark ID: 6, Coordinates: (372, 205)
# Landmark ID: 7, Coordinates: (358, 166)
# Landmark ID: 8, Coordinates: (348, 134)
# Landmark ID: 9, Coordinates: (438, 259)
# Landmark ID: 10, Coordinates: (419, 179)
# Landmark ID: 11, Coordinates: (409, 131)
# Landmark ID: 12, Coordinates: (403, 94)
# Landmark ID: 13, Coordinates: (479, 262)
# Landmark ID: 14, Coordinates: (466, 186)
# Landmark ID: 15, Coordinates: (456, 144)
# Landmark ID: 16, Coordinates: (448, 108)
# Landmark ID: 17, Coordinates: (524, 279)
# Landmark ID: 18, Coordinates: (532, 224)
# Landmark ID: 19, Coordinates: (534, 189)
# Landmark ID: 20, Coordinates: (535, 155)
# Landmark ID: 0, Coordinates: (64, 423)
# Landmark ID: 1, Coordinates: (122, 394)
# Landmark ID: 2, Coordinates: (173, 342)
# Landmark ID: 3, Coordinates: (201, 288)
# Landmark ID: 4, Coordinates: (229, 250)
# Landmark ID: 5, Coordinates: (121, 247)
# Landmark ID: 6, Coordinates: (141, 179)
# Landmark ID: 7, Coordinates: (146, 136)
# Landmark ID: 8, Coordinates: (146, 99)
# Landmark ID: 9, Coordinates: (82, 239)
# Landmark ID: 10, Coordinates: (88, 161)
# Landmark ID: 11, Coordinates: (85, 112)
# Landmark ID: 12, Coordinates: (77, 74)
# Landmark ID: 13, Coordinates: (47, 249)
# Landmark ID: 14, Coordinates: (45, 176)
# Landmark ID: 15, Coordinates: (38, 130)
# Landmark ID: 16, Coordinates: (31, 93)
# Landmark ID: 17, Coordinates: (14, 274)
# Landmark ID: 18, Coordinates: (-11, 228)
# Landmark ID: 19, Coordinates: (-30, 200)
# Landmark ID: 20, Coordinates: (-47, 177)
# Landmark ID: 0, Coordinates: (481, 444)
# Landmark ID: 1, Coordinates: (411, 431)
# Landmark ID: 2, Coordinates: (347, 388)
# Landmark ID: 3, Coordinates: (305, 345)
# Landmark ID: 4, Coordinates: (278, 302)
# Landmark ID: 5, Coordinates: (385, 268)
# Landmark ID: 6, Coordinates: (360, 199)
# Landmark ID: 7, Coordinates: (343, 161)
# Landmark ID: 8, Coordinates: (330, 128)
# Landmark ID: 9, Coordinates: (426, 255)
# Landmark ID: 10, Coordinates: (409, 175)
# Landmark ID: 11, Coordinates: (399, 128)
# Landmark ID: 12, Coordinates: (393, 91)
# Landmark ID: 13, Coordinates: (466, 259)
# Landmark ID: 14, Coordinates: (456, 182)
# Landmark ID: 15, Coordinates: (451, 140)
# Landmark ID: 16, Coordinates: (445, 102)
# Landmark ID: 17, Coordinates: (508, 277)
# Landmark ID: 18, Coordinates: (516, 224)
# Landmark ID: 19, Coordinates: (519, 190)
# Landmark ID: 20, Coordinates: (520, 158)
# Landmark ID: 0, Coordinates: (64, 417)
# Landmark ID: 1, Coordinates: (120, 389)
# Landmark ID: 2, Coordinates: (171, 337)
# Landmark ID: 3, Coordinates: (199, 283)
# Landmark ID: 4, Coordinates: (225, 246)
# Landmark ID: 5, Coordinates: (118, 245)
# Landmark ID: 6, Coordinates: (140, 179)
# Landmark ID: 7, Coordinates: (145, 137)
# Landmark ID: 8, Coordinates: (146, 102)
# Landmark ID: 9, Coordinates: (81, 237)
# Landmark ID: 10, Coordinates: (85, 160)
# Landmark ID: 11, Coordinates: (81, 111)
# Landmark ID: 12, Coordinates: (73, 74)
# Landmark ID: 13, Coordinates: (47, 247)
# Landmark ID: 14, Coordinates: (44, 176)
# Landmark ID: 15, Coordinates: (40, 133)
# Landmark ID: 16, Coordinates: (34, 97)
# Landmark ID: 17, Coordinates: (15, 272)
# Landmark ID: 18, Coordinates: (-9, 233)
# Landmark ID: 19, Coordinates: (-29, 207)
# Landmark ID: 20, Coordinates: (-46, 185)
# Landmark ID: 0, Coordinates: (481, 445)
# Landmark ID: 1, Coordinates: (408, 433)
# Landmark ID: 2, Coordinates: (344, 388)
# Landmark ID: 3, Coordinates: (304, 342)
# Landmark ID: 4, Coordinates: (279, 301)
# Landmark ID: 5, Coordinates: (384, 268)
# Landmark ID: 6, Coordinates: (360, 199)
# Landmark ID: 7, Coordinates: (344, 159)
# Landmark ID: 8, Coordinates: (330, 125)
# Landmark ID: 9, Coordinates: (425, 253)
# Landmark ID: 10, Coordinates: (408, 173)
# Landmark ID: 11, Coordinates: (399, 126)
# Landmark ID: 12, Coordinates: (392, 89)
# Landmark ID: 13, Coordinates: (465, 257)
# Landmark ID: 14, Coordinates: (456, 179)
# Landmark ID: 15, Coordinates: (449, 138)
# Landmark ID: 16, Coordinates: (441, 102)
# Landmark ID: 17, Coordinates: (507, 275)
# Landmark ID: 18, Coordinates: (518, 222)
# Landmark ID: 19, Coordinates: (520, 188)
# Landmark ID: 20, Coordinates: (520, 156)
# Landmark ID: 0, Coordinates: (65, 415)
# Landmark ID: 1, Coordinates: (121, 388)
# Landmark ID: 2, Coordinates: (171, 337)
# Landmark ID: 3, Coordinates: (199, 284)
# Landmark ID: 4, Coordinates: (225, 245)
# Landmark ID: 5, Coordinates: (117, 246)
# Landmark ID: 6, Coordinates: (140, 180)
# Landmark ID: 7, Coordinates: (145, 137)
# Landmark ID: 8, Coordinates: (146, 101)
# Landmark ID: 9, Coordinates: (80, 238)
# Landmark ID: 10, Coordinates: (85, 160)
# Landmark ID: 11, Coordinates: (81, 110)
# Landmark ID: 12, Coordinates: (73, 73)
# Landmark ID: 13, Coordinates: (47, 248)
# Landmark ID: 14, Coordinates: (45, 176)
# Landmark ID: 15, Coordinates: (40, 132)
# Landmark ID: 16, Coordinates: (34, 96)
# Landmark ID: 17, Coordinates: (16, 272)
# Landmark ID: 18, Coordinates: (-8, 233)
# Landmark ID: 19, Coordinates: (-27, 207)
# Landmark ID: 20, Coordinates: (-44, 184)
# Landmark ID: 0, Coordinates: (474, 443)
# Landmark ID: 1, Coordinates: (400, 430)
# Landmark ID: 2, Coordinates: (336, 385)
# Landmark ID: 3, Coordinates: (296, 340)
# Landmark ID: 4, Coordinates: (273, 298)
# Landmark ID: 5, Coordinates: (380, 266)
# Landmark ID: 6, Coordinates: (353, 197)
# Landmark ID: 7, Coordinates: (335, 157)
# Landmark ID: 8, Coordinates: (322, 122)
# Landmark ID: 9, Coordinates: (420, 253)
# Landmark ID: 10, Coordinates: (402, 173)
# Landmark ID: 11, Coordinates: (391, 126)
# Landmark ID: 12, Coordinates: (385, 89)
# Landmark ID: 13, Coordinates: (460, 257)
# Landmark ID: 14, Coordinates: (449, 180)
# Landmark ID: 15, Coordinates: (442, 137)
# Landmark ID: 16, Coordinates: (435, 100)
# Landmark ID: 17, Coordinates: (503, 273)
# Landmark ID: 18, Coordinates: (509, 219)
# Landmark ID: 19, Coordinates: (512, 186)
# Landmark ID: 20, Coordinates: (514, 153)
# Landmark ID: 0, Coordinates: (61, 415)
# Landmark ID: 1, Coordinates: (117, 386)
# Landmark ID: 2, Coordinates: (167, 335)
# Landmark ID: 3, Coordinates: (197, 284)
# Landmark ID: 4, Coordinates: (222, 247)
# Landmark ID: 5, Coordinates: (116, 244)
# Landmark ID: 6, Coordinates: (137, 178)
# Landmark ID: 7, Coordinates: (142, 136)
# Landmark ID: 8, Coordinates: (142, 101)
# Landmark ID: 9, Coordinates: (78, 236)
# Landmark ID: 10, Coordinates: (83, 160)
# Landmark ID: 11, Coordinates: (79, 111)
# Landmark ID: 12, Coordinates: (71, 75)
# Landmark ID: 13, Coordinates: (43, 247)
# Landmark ID: 14, Coordinates: (42, 176)
# Landmark ID: 15, Coordinates: (37, 133)
# Landmark ID: 16, Coordinates: (32, 98)
# Landmark ID: 17, Coordinates: (9, 272)
# Landmark ID: 18, Coordinates: (-14, 229)
# Landmark ID: 19, Coordinates: (-32, 200)
# Landmark ID: 20, Coordinates: (-47, 175)
# Landmark ID: 0, Coordinates: (474, 442)
# Landmark ID: 1, Coordinates: (399, 430)
# Landmark ID: 2, Coordinates: (335, 385)
# Landmark ID: 3, Coordinates: (295, 339)
# Landmark ID: 4, Coordinates: (271, 298)
# Landmark ID: 5, Coordinates: (378, 267)
# Landmark ID: 6, Coordinates: (352, 197)
# Landmark ID: 7, Coordinates: (336, 156)
# Landmark ID: 8, Coordinates: (322, 120)
# Landmark ID: 9, Coordinates: (419, 253)
# Landmark ID: 10, Coordinates: (403, 172)
# Landmark ID: 11, Coordinates: (394, 124)
# Landmark ID: 12, Coordinates: (387, 87)
# Landmark ID: 13, Coordinates: (459, 256)
# Landmark ID: 14, Coordinates: (448, 179)
# Landmark ID: 15, Coordinates: (440, 136)
# Landmark ID: 16, Coordinates: (432, 99)
# Landmark ID: 17, Coordinates: (502, 272)
# Landmark ID: 18, Coordinates: (510, 218)
# Landmark ID: 19, Coordinates: (514, 184)
# Landmark ID: 20, Coordinates: (516, 152)
# Landmark ID: 0, Coordinates: (61, 413)
# Landmark ID: 1, Coordinates: (117, 386)
# Landmark ID: 2, Coordinates: (167, 337)
# Landmark ID: 3, Coordinates: (196, 285)
# Landmark ID: 4, Coordinates: (222, 246)
# Landmark ID: 5, Coordinates: (115, 244)
# Landmark ID: 6, Coordinates: (137, 179)
# Landmark ID: 7, Coordinates: (142, 137)
# Landmark ID: 8, Coordinates: (143, 102)
# Landmark ID: 9, Coordinates: (77, 236)
# Landmark ID: 10, Coordinates: (81, 158)
# Landmark ID: 11, Coordinates: (78, 109)
# Landmark ID: 12, Coordinates: (71, 73)
# Landmark ID: 13, Coordinates: (43, 247)
# Landmark ID: 14, Coordinates: (41, 176)
# Landmark ID: 15, Coordinates: (36, 132)
# Landmark ID: 16, Coordinates: (30, 97)
# Landmark ID: 17, Coordinates: (10, 272)
# Landmark ID: 18, Coordinates: (-13, 231)
# Landmark ID: 19, Coordinates: (-31, 204)
# Landmark ID: 20, Coordinates: (-47, 180)
# Landmark ID: 0, Coordinates: (476, 443)
# Landmark ID: 1, Coordinates: (401, 432)
# Landmark ID: 2, Coordinates: (336, 387)
# Landmark ID: 3, Coordinates: (296, 340)
# Landmark ID: 4, Coordinates: (271, 298)
# Landmark ID: 5, Coordinates: (381, 266)
# Landmark ID: 6, Coordinates: (354, 197)
# Landmark ID: 7, Coordinates: (336, 155)
# Landmark ID: 8, Coordinates: (323, 120)
# Landmark ID: 9, Coordinates: (422, 251)
# Landmark ID: 10, Coordinates: (405, 170)
# Landmark ID: 11, Coordinates: (396, 123)
# Landmark ID: 12, Coordinates: (389, 86)
# Landmark ID: 13, Coordinates: (461, 255)
# Landmark ID: 14, Coordinates: (450, 177)
# Landmark ID: 15, Coordinates: (442, 135)
# Landmark ID: 16, Coordinates: (433, 98)
# Landmark ID: 17, Coordinates: (503, 271)
# Landmark ID: 18, Coordinates: (512, 216)
# Landmark ID: 19, Coordinates: (515, 183)
# Landmark ID: 20, Coordinates: (517, 151)
# Landmark ID: 0, Coordinates: (59, 411)
# Landmark ID: 1, Coordinates: (113, 384)
# Landmark ID: 2, Coordinates: (163, 334)
# Landmark ID: 3, Coordinates: (192, 282)
# Landmark ID: 4, Coordinates: (216, 245)
# Landmark ID: 5, Coordinates: (110, 244)
# Landmark ID: 6, Coordinates: (131, 179)
# Landmark ID: 7, Coordinates: (137, 137)
# Landmark ID: 8, Coordinates: (138, 102)
# Landmark ID: 9, Coordinates: (72, 237)
# Landmark ID: 10, Coordinates: (77, 161)
# Landmark ID: 11, Coordinates: (72, 112)
# Landmark ID: 12, Coordinates: (65, 76)
# Landmark ID: 13, Coordinates: (39, 248)
# Landmark ID: 14, Coordinates: (35, 177)
# Landmark ID: 15, Coordinates: (28, 134)
# Landmark ID: 16, Coordinates: (20, 99)
# Landmark ID: 17, Coordinates: (7, 272)
# Landmark ID: 18, Coordinates: (-15, 229)
# Landmark ID: 19, Coordinates: (-33, 203)
# Landmark ID: 20, Coordinates: (-48, 179)
# Landmark ID: 0, Coordinates: (482, 441)
# Landmark ID: 1, Coordinates: (404, 430)
# Landmark ID: 2, Coordinates: (338, 384)
# Landmark ID: 3, Coordinates: (298, 335)
# Landmark ID: 4, Coordinates: (271, 297)
# Landmark ID: 5, Coordinates: (383, 265)
# Landmark ID: 6, Coordinates: (356, 196)
# Landmark ID: 7, Coordinates: (340, 155)
# Landmark ID: 8, Coordinates: (327, 119)
# Landmark ID: 9, Coordinates: (425, 250)
# Landmark ID: 10, Coordinates: (409, 169)
# Landmark ID: 11, Coordinates: (400, 122)
# Landmark ID: 12, Coordinates: (391, 86)
# Landmark ID: 13, Coordinates: (465, 253)
# Landmark ID: 14, Coordinates: (453, 176)
# Landmark ID: 15, Coordinates: (444, 135)
# Landmark ID: 16, Coordinates: (434, 99)
# Landmark ID: 17, Coordinates: (507, 269)
# Landmark ID: 18, Coordinates: (516, 216)
# Landmark ID: 19, Coordinates: (519, 183)
# Landmark ID: 20, Coordinates: (520, 153)
# Landmark ID: 0, Coordinates: (48, 411)
# Landmark ID: 1, Coordinates: (107, 386)
# Landmark ID: 2, Coordinates: (158, 335)
# Landmark ID: 3, Coordinates: (188, 283)
# Landmark ID: 4, Coordinates: (213, 245)
# Landmark ID: 5, Coordinates: (106, 244)
# Landmark ID: 6, Coordinates: (127, 179)
# Landmark ID: 7, Coordinates: (132, 137)
# Landmark ID: 8, Coordinates: (132, 101)
# Landmark ID: 9, Coordinates: (67, 236)
# Landmark ID: 10, Coordinates: (69, 160)
# Landmark ID: 11, Coordinates: (65, 111)
# Landmark ID: 12, Coordinates: (58, 75)
# Landmark ID: 13, Coordinates: (32, 246)
# Landmark ID: 14, Coordinates: (28, 175)
# Landmark ID: 15, Coordinates: (21, 132)
# Landmark ID: 16, Coordinates: (14, 97)
# Landmark ID: 17, Coordinates: (0, 269)
# Landmark ID: 18, Coordinates: (-23, 226)
# Landmark ID: 19, Coordinates: (-40, 198)
# Landmark ID: 20, Coordinates: (-54, 174)
# Landmark ID: 0, Coordinates: (481, 444)
# Landmark ID: 1, Coordinates: (403, 432)
# Landmark ID: 2, Coordinates: (339, 384)
# Landmark ID: 3, Coordinates: (300, 336)
# Landmark ID: 4, Coordinates: (272, 297)
# Landmark ID: 5, Coordinates: (384, 265)
# Landmark ID: 6, Coordinates: (357, 196)
# Landmark ID: 7, Coordinates: (340, 155)
# Landmark ID: 8, Coordinates: (327, 120)
# Landmark ID: 9, Coordinates: (426, 250)
# Landmark ID: 10, Coordinates: (409, 170)
# Landmark ID: 11, Coordinates: (400, 123)
# Landmark ID: 12, Coordinates: (392, 87)
# Landmark ID: 13, Coordinates: (465, 254)
# Landmark ID: 14, Coordinates: (454, 176)
# Landmark ID: 15, Coordinates: (445, 135)
# Landmark ID: 16, Coordinates: (436, 99)
# Landmark ID: 17, Coordinates: (508, 270)
# Landmark ID: 18, Coordinates: (516, 217)
# Landmark ID: 19, Coordinates: (518, 183)
# Landmark ID: 20, Coordinates: (518, 152)
# Landmark ID: 0, Coordinates: (52, 412)
# Landmark ID: 1, Coordinates: (108, 386)
# Landmark ID: 2, Coordinates: (158, 336)
# Landmark ID: 3, Coordinates: (188, 284)
# Landmark ID: 4, Coordinates: (211, 244)
# Landmark ID: 5, Coordinates: (104, 245)
# Landmark ID: 6, Coordinates: (126, 179)
# Landmark ID: 7, Coordinates: (131, 138)
# Landmark ID: 8, Coordinates: (132, 102)
# Landmark ID: 9, Coordinates: (66, 237)
# Landmark ID: 10, Coordinates: (69, 161)
# Landmark ID: 11, Coordinates: (65, 112)
# Landmark ID: 12, Coordinates: (57, 76)
# Landmark ID: 13, Coordinates: (32, 248)
# Landmark ID: 14, Coordinates: (27, 177)
# Landmark ID: 15, Coordinates: (21, 134)
# Landmark ID: 16, Coordinates: (13, 99)
# Landmark ID: 17, Coordinates: (1, 271)
# Landmark ID: 18, Coordinates: (-22, 230)
# Landmark ID: 19, Coordinates: (-40, 204)
# Landmark ID: 20, Coordinates: (-57, 182)
# Landmark ID: 0, Coordinates: (482, 448)
# Landmark ID: 1, Coordinates: (405, 434)
# Landmark ID: 2, Coordinates: (342, 384)
# Landmark ID: 3, Coordinates: (302, 335)
# Landmark ID: 4, Coordinates: (275, 296)
# Landmark ID: 5, Coordinates: (386, 268)
# Landmark ID: 6, Coordinates: (359, 198)
# Landmark ID: 7, Coordinates: (343, 156)
# Landmark ID: 8, Coordinates: (330, 120)
# Landmark ID: 9, Coordinates: (428, 254)
# Landmark ID: 10, Coordinates: (413, 172)
# Landmark ID: 11, Coordinates: (404, 124)
# Landmark ID: 12, Coordinates: (397, 87)
# Landmark ID: 13, Coordinates: (467, 257)
# Landmark ID: 14, Coordinates: (456, 178)
# Landmark ID: 15, Coordinates: (448, 136)
# Landmark ID: 16, Coordinates: (439, 100)
# Landmark ID: 17, Coordinates: (509, 273)
# Landmark ID: 18, Coordinates: (517, 219)
# Landmark ID: 19, Coordinates: (520, 185)
# Landmark ID: 20, Coordinates: (522, 153)
# Landmark ID: 0, Coordinates: (54, 408)
# Landmark ID: 1, Coordinates: (110, 384)
# Landmark ID: 2, Coordinates: (159, 335)
# Landmark ID: 3, Coordinates: (187, 282)
# Landmark ID: 4, Coordinates: (211, 243)
# Landmark ID: 5, Coordinates: (104, 243)
# Landmark ID: 6, Coordinates: (125, 179)
# Landmark ID: 7, Coordinates: (130, 137)
# Landmark ID: 8, Coordinates: (131, 101)
# Landmark ID: 9, Coordinates: (67, 236)
# Landmark ID: 10, Coordinates: (68, 160)
# Landmark ID: 11, Coordinates: (63, 112)
# Landmark ID: 12, Coordinates: (55, 75)
# Landmark ID: 13, Coordinates: (33, 247)
# Landmark ID: 14, Coordinates: (27, 177)
# ...
# Landmark ID: 4, Coordinates: (225, 267)
# Landmark ID: 5, Coordinates: (81, 296)
# Landmark ID: 6, Coordinates: (151, 239)
# Landmark ID: 7, Coordinates: (197, 231)
# Landmark ID: 8, Coordinates: (227, 237)
# Landmark ID: 9, Coordinates: (70, 295)
# Landmark ID: 10, Coordinates: (150, 241)
# Landmark ID: 11, Coordinates: (197, 243)
# Landmark ID: 12, Coordinates: (229, 248)
# Landmark ID: 13, Coordinates: (78, 300)
# Landmark ID: 14, Coordinates: (159, 258)
# Landmark ID: 15, Coordinates: (195, 256)
# Landmark ID: 16, Coordinates: (222, 256)
# Landmark ID: 17, Coordinates: (97, 307)
# Landmark ID: 18, Coordinates: (161, 277)
# Landmark ID: 19, Coordinates: (191, 272)
# Landmark ID: 20, Coordinates: (213, 271)
# Landmark ID: 0, Coordinates: (537, 402)
# Landmark ID: 1, Coordinates: (560, 338)
# Landmark ID: 2, Coordinates: (547, 276)
# Landmark ID: 3, Coordinates: (516, 238)
# Landmark ID: 4, Coordinates: (486, 215)
# Landmark ID: 5, Coordinates: (543, 264)
# Landmark ID: 6, Coordinates: (518, 194)
# Landmark ID: 7, Coordinates: (492, 158)
# Landmark ID: 8, Coordinates: (468, 138)
# Landmark ID: 9, Coordinates: (504, 278)
# Landmark ID: 10, Coordinates: (461, 204)
# Landmark ID: 11, Coordinates: (430, 164)
# Landmark ID: 12, Coordinates: (404, 140)
# Landmark ID: 13, Coordinates: (467, 300)
# Landmark ID: 14, Coordinates: (420, 235)
# Landmark ID: 15, Coordinates: (389, 198)
# Landmark ID: 16, Coordinates: (364, 171)
# Landmark ID: 17, Coordinates: (435, 327)
# Landmark ID: 18, Coordinates: (394, 288)
# Landmark ID: 19, Coordinates: (368, 264)
# Landmark ID: 20, Coordinates: (346, 245)
# Landmark ID: 0, Coordinates: (109, 414)
# Landmark ID: 1, Coordinates: (85, 363)
# Landmark ID: 2, Coordinates: (91, 308)
# Landmark ID: 3, Coordinates: (121, 268)
# Landmark ID: 4, Coordinates: (154, 249)
# Landmark ID: 5, Coordinates: (83, 286)
# Landmark ID: 6, Coordinates: (137, 235)
# Landmark ID: 7, Coordinates: (174, 209)
# Landmark ID: 8, Coordinates: (203, 193)
# Landmark ID: 9, Coordinates: (116, 303)
# Landmark ID: 10, Coordinates: (167, 242)
# Landmark ID: 11, Coordinates: (203, 214)
# Landmark ID: 12, Coordinates: (230, 196)
# Landmark ID: 13, Coordinates: (150, 326)
# Landmark ID: 14, Coordinates: (197, 273)
# Landmark ID: 15, Coordinates: (226, 248)
# Landmark ID: 16, Coordinates: (247, 230)
# Landmark ID: 17, Coordinates: (182, 351)
# Landmark ID: 18, Coordinates: (217, 315)
# Landmark ID: 19, Coordinates: (236, 294)
# Landmark ID: 20, Coordinates: (249, 279)
# Landmark ID: 0, Coordinates: (538, 399)
# Landmark ID: 1, Coordinates: (563, 332)
# Landmark ID: 2, Coordinates: (552, 271)
# Landmark ID: 3, Coordinates: (522, 233)
# Landmark ID: 4, Coordinates: (490, 214)
# Landmark ID: 5, Coordinates: (540, 257)
# Landmark ID: 6, Coordinates: (510, 184)
# Landmark ID: 7, Coordinates: (482, 150)
# Landmark ID: 8, Coordinates: (459, 134)
# Landmark ID: 9, Coordinates: (500, 273)
# Landmark ID: 10, Coordinates: (456, 201)
# Landmark ID: 11, Coordinates: (426, 164)
# Landmark ID: 12, Coordinates: (402, 142)
# Landmark ID: 13, Coordinates: (463, 298)
# Landmark ID: 14, Coordinates: (417, 234)
# Landmark ID: 15, Coordinates: (388, 198)
# Landmark ID: 16, Coordinates: (365, 173)
# Landmark ID: 17, Coordinates: (434, 328)
# Landmark ID: 18, Coordinates: (393, 290)
# Landmark ID: 19, Coordinates: (368, 267)
# Landmark ID: 20, Coordinates: (347, 250)
# Landmark ID: 0, Coordinates: (538, 396)
# Landmark ID: 1, Coordinates: (558, 328)
# Landmark ID: 2, Coordinates: (542, 270)
# Landmark ID: 3, Coordinates: (517, 230)
# Landmark ID: 4, Coordinates: (496, 204)
# Landmark ID: 5, Coordinates: (529, 248)
# Landmark ID: 6, Coordinates: (522, 177)
# Landmark ID: 7, Coordinates: (508, 136)
# Landmark ID: 8, Coordinates: (498, 108)
# Landmark ID: 9, Coordinates: (489, 263)
# Landmark ID: 10, Coordinates: (451, 185)
# Landmark ID: 11, Coordinates: (423, 138)
# Landmark ID: 12, Coordinates: (400, 104)
# Landmark ID: 13, Coordinates: (455, 293)
# Landmark ID: 14, Coordinates: (401, 238)
# Landmark ID: 15, Coordinates: (366, 200)
# Landmark ID: 16, Coordinates: (339, 168)
# Landmark ID: 17, Coordinates: (432, 335)
# Landmark ID: 18, Coordinates: (376, 315)
# Landmark ID: 19, Coordinates: (341, 301)
# Landmark ID: 20, Coordinates: (313, 285)
# Landmark ID: 0, Coordinates: (539, 404)
# Landmark ID: 1, Coordinates: (561, 333)
# Landmark ID: 2, Coordinates: (543, 279)
# Landmark ID: 3, Coordinates: (510, 250)
# Landmark ID: 4, Coordinates: (479, 240)
# Landmark ID: 5, Coordinates: (534, 248)
# Landmark ID: 6, Coordinates: (524, 173)
# Landmark ID: 7, Coordinates: (510, 129)
# Landmark ID: 8, Coordinates: (497, 99)
# Landmark ID: 9, Coordinates: (493, 262)
# Landmark ID: 10, Coordinates: (450, 181)
# Landmark ID: 11, Coordinates: (421, 134)
# Landmark ID: 12, Coordinates: (398, 101)
# Landmark ID: 13, Coordinates: (458, 293)
# Landmark ID: 14, Coordinates: (400, 236)
# Landmark ID: 15, Coordinates: (365, 202)
# Landmark ID: 16, Coordinates: (340, 176)
# Landmark ID: 17, Coordinates: (433, 334)
# Landmark ID: 18, Coordinates: (375, 311)
# Landmark ID: 19, Coordinates: (340, 297)
# Landmark ID: 20, Coordinates: (312, 282)
# Landmark ID: 0, Coordinates: (539, 404)
# Landmark ID: 1, Coordinates: (554, 324)
# Landmark ID: 2, Coordinates: (533, 266)
# Landmark ID: 3, Coordinates: (499, 233)
# Landmark ID: 4, Coordinates: (469, 217)
# Landmark ID: 5, Coordinates: (528, 245)
# Landmark ID: 6, Coordinates: (522, 166)
# Landmark ID: 7, Coordinates: (511, 122)
# Landmark ID: 8, Coordinates: (502, 91)
# Landmark ID: 9, Coordinates: (489, 263)
# Landmark ID: 10, Coordinates: (453, 179)
# Landmark ID: 11, Coordinates: (429, 127)
# Landmark ID: 12, Coordinates: (410, 91)
# Landmark ID: 13, Coordinates: (453, 297)
# Landmark ID: 14, Coordinates: (399, 234)
# Landmark ID: 15, Coordinates: (369, 195)
# Landmark ID: 16, Coordinates: (347, 164)
# Landmark ID: 17, Coordinates: (427, 339)
# Landmark ID: 18, Coordinates: (370, 313)
# Landmark ID: 19, Coordinates: (336, 299)
# Landmark ID: 20, Coordinates: (308, 284)
# Landmark ID: 0, Coordinates: (545, 410)
# Landmark ID: 1, Coordinates: (558, 332)
# Landmark ID: 2, Coordinates: (534, 273)
# Landmark ID: 3, Coordinates: (496, 245)
# Landmark ID: 4, Coordinates: (462, 236)
# Landmark ID: 5, Coordinates: (530, 248)
# Landmark ID: 6, Coordinates: (523, 167)
# Landmark ID: 7, Coordinates: (510, 122)
# Landmark ID: 8, Coordinates: (499, 89)
# Landmark ID: 9, Coordinates: (491, 264)
# Landmark ID: 10, Coordinates: (453, 180)
# Landmark ID: 11, Coordinates: (426, 129)
# Landmark ID: 12, Coordinates: (404, 92)
# Landmark ID: 13, Coordinates: (456, 296)
# Landmark ID: 14, Coordinates: (401, 237)
# Landmark ID: 15, Coordinates: (369, 198)
# Landmark ID: 16, Coordinates: (346, 167)
# Landmark ID: 17, Coordinates: (429, 337)
# Landmark ID: 18, Coordinates: (373, 312)
# Landmark ID: 19, Coordinates: (339, 295)
# Landmark ID: 20, Coordinates: (312, 277)
# Landmark ID: 0, Coordinates: (545, 415)
# Landmark ID: 1, Coordinates: (561, 336)
# Landmark ID: 2, Coordinates: (541, 276)
# Landmark ID: 3, Coordinates: (506, 246)
# Landmark ID: 4, Coordinates: (474, 234)
# Landmark ID: 5, Coordinates: (528, 249)
# Landmark ID: 6, Coordinates: (520, 169)
# Landmark ID: 7, Coordinates: (509, 125)
# Landmark ID: 8, Coordinates: (500, 93)
# Landmark ID: 9, Coordinates: (490, 264)
# Landmark ID: 10, Coordinates: (453, 179)
# Landmark ID: 11, Coordinates: (426, 128)
# Landmark ID: 12, Coordinates: (404, 92)
# Landmark ID: 13, Coordinates: (456, 296)
# Landmark ID: 14, Coordinates: (400, 235)
# Landmark ID: 15, Coordinates: (368, 197)
# Landmark ID: 16, Coordinates: (344, 167)
# Landmark ID: 17, Coordinates: (430, 338)
# Landmark ID: 18, Coordinates: (373, 312)
# Landmark ID: 19, Coordinates: (339, 294)
# Landmark ID: 20, Coordinates: (311, 277)
# Landmark ID: 0, Coordinates: (542, 420)
# Landmark ID: 1, Coordinates: (558, 344)
# Landmark ID: 2, Coordinates: (545, 287)
# Landmark ID: 3, Coordinates: (513, 262)
# Landmark ID: 4, Coordinates: (479, 253)
# Landmark ID: 5, Coordinates: (538, 261)
# Landmark ID: 6, Coordinates: (523, 183)
# Landmark ID: 7, Coordinates: (506, 143)
# Landmark ID: 8, Coordinates: (493, 115)
# Landmark ID: 9, Coordinates: (499, 274)
# Landmark ID: 10, Coordinates: (452, 192)
# Landmark ID: 11, Coordinates: (420, 150)
# Landmark ID: 12, Coordinates: (394, 121)
# Landmark ID: 13, Coordinates: (465, 299)
# Landmark ID: 14, Coordinates: (410, 236)
# Landmark ID: 15, Coordinates: (376, 203)
# Landmark ID: 16, Coordinates: (350, 178)
# Landmark ID: 17, Coordinates: (439, 328)
# Landmark ID: 18, Coordinates: (392, 288)
# Landmark ID: 19, Coordinates: (365, 267)
# Landmark ID: 20, Coordinates: (343, 249)
# Landmark ID: 0, Coordinates: (543, 428)
# Landmark ID: 1, Coordinates: (564, 355)
# Landmark ID: 2, Coordinates: (551, 290)
# Landmark ID: 3, Coordinates: (508, 258)
# Landmark ID: 4, Coordinates: (464, 248)
# Landmark ID: 5, Coordinates: (561, 270)
# Landmark ID: 6, Coordinates: (506, 198)
# Landmark ID: 7, Coordinates: (471, 173)
# Landmark ID: 8, Coordinates: (448, 162)
# Landmark ID: 9, Coordinates: (520, 291)
# Landmark ID: 10, Coordinates: (457, 210)
# Landmark ID: 11, Coordinates: (427, 184)
# Landmark ID: 12, Coordinates: (411, 170)
# Landmark ID: 13, Coordinates: (482, 315)
# Landmark ID: 14, Coordinates: (422, 239)
# Landmark ID: 15, Coordinates: (404, 220)
# Landmark ID: 16, Coordinates: (400, 211)
# Landmark ID: 17, Coordinates: (448, 335)
# Landmark ID: 18, Coordinates: (414, 275)
# Landmark ID: 19, Coordinates: (405, 254)
# Landmark ID: 20, Coordinates: (401, 241)
# Landmark ID: 0, Coordinates: (542, 420)
# Landmark ID: 1, Coordinates: (565, 351)
# Landmark ID: 2, Coordinates: (555, 287)
# Landmark ID: 3, Coordinates: (517, 253)
# Landmark ID: 4, Coordinates: (478, 242)
# Landmark ID: 5, Coordinates: (558, 270)
# Landmark ID: 6, Coordinates: (507, 198)
# Landmark ID: 7, Coordinates: (471, 174)
# Landmark ID: 8, Coordinates: (448, 164)
# Landmark ID: 9, Coordinates: (517, 291)
# Landmark ID: 10, Coordinates: (457, 212)
# Landmark ID: 11, Coordinates: (427, 189)
# Landmark ID: 12, Coordinates: (411, 177)
# Landmark ID: 13, Coordinates: (479, 313)
# Landmark ID: 14, Coordinates: (425, 240)
# Landmark ID: 15, Coordinates: (399, 216)
# Landmark ID: 16, Coordinates: (387, 202)
# Landmark ID: 17, Coordinates: (447, 335)
# Landmark ID: 18, Coordinates: (413, 275)
# Landmark ID: 19, Coordinates: (398, 251)
# Landmark ID: 20, Coordinates: (390, 233)
# Landmark ID: 0, Coordinates: (546, 423)
# Landmark ID: 1, Coordinates: (564, 355)
# Landmark ID: 2, Coordinates: (556, 293)
# Landmark ID: 3, Coordinates: (522, 259)
# Landmark ID: 4, Coordinates: (484, 250)
# Landmark ID: 5, Coordinates: (559, 271)
# Landmark ID: 6, Coordinates: (491, 213)
# Landmark ID: 7, Coordinates: (456, 207)
# Landmark ID: 8, Coordinates: (440, 211)
# Landmark ID: 9, Coordinates: (526, 293)
# Landmark ID: 10, Coordinates: (460, 226)
# Landmark ID: 11, Coordinates: (429, 216)
# Landmark ID: 12, Coordinates: (416, 215)
# Landmark ID: 13, Coordinates: (491, 317)
# Landmark ID: 14, Coordinates: (436, 254)
# Landmark ID: 15, Coordinates: (414, 240)
# Landmark ID: 16, Coordinates: (407, 235)
# Landmark ID: 17, Coordinates: (460, 341)
# Landmark ID: 18, Coordinates: (426, 287)
# Landmark ID: 19, Coordinates: (414, 268)
# Landmark ID: 20, Coordinates: (410, 256)
# Landmark ID: 0, Coordinates: (541, 419)
# Landmark ID: 1, Coordinates: (562, 351)
# Landmark ID: 2, Coordinates: (554, 290)
# Landmark ID: 3, Coordinates: (516, 256)
# Landmark ID: 4, Coordinates: (478, 248)
# Landmark ID: 5, Coordinates: (560, 268)
# Landmark ID: 6, Coordinates: (488, 212)
# Landmark ID: 7, Coordinates: (450, 206)
# Landmark ID: 8, Coordinates: (431, 209)
# Landmark ID: 9, Coordinates: (526, 290)
# Landmark ID: 10, Coordinates: (456, 224)
# Landmark ID: 11, Coordinates: (424, 215)
# Landmark ID: 12, Coordinates: (410, 218)
# Landmark ID: 13, Coordinates: (491, 313)
# Landmark ID: 14, Coordinates: (433, 252)
# Landmark ID: 15, Coordinates: (411, 240)
# Landmark ID: 16, Coordinates: (405, 239)
# Landmark ID: 17, Coordinates: (460, 337)
# Landmark ID: 18, Coordinates: (423, 286)
# Landmark ID: 19, Coordinates: (413, 269)
# Landmark ID: 20, Coordinates: (410, 258)
# Landmark ID: 0, Coordinates: (543, 417)
# Landmark ID: 1, Coordinates: (563, 349)
# Landmark ID: 2, Coordinates: (553, 289)
# Landmark ID: 3, Coordinates: (516, 255)
# Landmark ID: 4, Coordinates: (477, 247)
# Landmark ID: 5, Coordinates: (559, 269)
# Landmark ID: 6, Coordinates: (487, 212)
# Landmark ID: 7, Coordinates: (448, 205)
# Landmark ID: 8, Coordinates: (429, 208)
# Landmark ID: 9, Coordinates: (525, 291)
# Landmark ID: 10, Coordinates: (456, 224)
# Landmark ID: 11, Coordinates: (424, 214)
# Landmark ID: 12, Coordinates: (410, 217)
# Landmark ID: 13, Coordinates: (489, 314)
# Landmark ID: 14, Coordinates: (433, 251)
# Landmark ID: 15, Coordinates: (412, 239)
# Landmark ID: 16, Coordinates: (406, 238)
# Landmark ID: 17, Coordinates: (457, 338)
# Landmark ID: 18, Coordinates: (422, 285)
# Landmark ID: 19, Coordinates: (413, 269)
# Landmark ID: 20, Coordinates: (411, 259)
# Landmark ID: 0, Coordinates: (544, 421)
# Landmark ID: 1, Coordinates: (561, 353)
# Landmark ID: 2, Coordinates: (553, 294)
# Landmark ID: 3, Coordinates: (518, 261)
# Landmark ID: 4, Coordinates: (479, 252)
# Landmark ID: 5, Coordinates: (557, 272)
# Landmark ID: 6, Coordinates: (487, 215)
# Landmark ID: 7, Coordinates: (449, 208)
# Landmark ID: 8, Coordinates: (429, 211)
# Landmark ID: 9, Coordinates: (524, 293)
# Landmark ID: 10, Coordinates: (455, 226)
# Landmark ID: 11, Coordinates: (423, 216)
# Landmark ID: 12, Coordinates: (409, 219)
# Landmark ID: 13, Coordinates: (489, 315)
# Landmark ID: 14, Coordinates: (432, 254)
# Landmark ID: 15, Coordinates: (411, 242)
# Landmark ID: 16, Coordinates: (405, 241)
# Landmark ID: 17, Coordinates: (458, 340)
# Landmark ID: 18, Coordinates: (422, 289)
# Landmark ID: 19, Coordinates: (412, 275)
# Landmark ID: 20, Coordinates: (411, 269)
# Landmark ID: 0, Coordinates: (540, 417)
# Landmark ID: 1, Coordinates: (561, 350)
# Landmark ID: 2, Coordinates: (553, 291)
# Landmark ID: 3, Coordinates: (515, 256)
# Landmark ID: 4, Coordinates: (476, 247)
# Landmark ID: 5, Coordinates: (558, 270)
# Landmark ID: 6, Coordinates: (487, 214)
# Landmark ID: 7, Coordinates: (448, 208)
# Landmark ID: 8, Coordinates: (429, 212)
# Landmark ID: 9, Coordinates: (524, 292)
# Landmark ID: 10, Coordinates: (454, 226)
# Landmark ID: 11, Coordinates: (421, 217)
# Landmark ID: 12, Coordinates: (409, 220)
# Landmark ID: 13, Coordinates: (489, 315)
# Landmark ID: 14, Coordinates: (429, 254)
# Landmark ID: 15, Coordinates: (409, 243)
# Landmark ID: 16, Coordinates: (404, 242)
# Landmark ID: 17, Coordinates: (458, 339)
# Landmark ID: 18, Coordinates: (423, 289)
# Landmark ID: 19, Coordinates: (416, 274)
# Landmark ID: 20, Coordinates: (416, 267)
# Landmark ID: 0, Coordinates: (543, 419)
# Landmark ID: 1, Coordinates: (561, 352)
# Landmark ID: 2, Coordinates: (551, 291)
# Landmark ID: 3, Coordinates: (512, 257)
# Landmark ID: 4, Coordinates: (472, 248)
# Landmark ID: 5, Coordinates: (559, 269)
# Landmark ID: 6, Coordinates: (487, 215)
# Landmark ID: 7, Coordinates: (446, 207)
# Landmark ID: 8, Coordinates: (425, 210)
# Landmark ID: 9, Coordinates: (526, 292)
# Landmark ID: 10, Coordinates: (455, 226)
# Landmark ID: 11, Coordinates: (423, 215)
# Landmark ID: 12, Coordinates: (409, 218)
# Landmark ID: 13, Coordinates: (490, 316)
# Landmark ID: 14, Coordinates: (431, 254)
# Landmark ID: 15, Coordinates: (411, 242)
# Landmark ID: 16, Coordinates: (407, 241)
# Landmark ID: 17, Coordinates: (457, 339)
# Landmark ID: 18, Coordinates: (423, 288)
# Landmark ID: 19, Coordinates: (416, 275)
# Landmark ID: 20, Coordinates: (417, 269)
# Landmark ID: 0, Coordinates: (533, 437)
# Landmark ID: 1, Coordinates: (482, 401)
# Landmark ID: 2, Coordinates: (454, 337)
# Landmark ID: 3, Coordinates: (432, 292)
# Landmark ID: 4, Coordinates: (408, 261)
# Landmark ID: 5, Coordinates: (526, 280)
# Landmark ID: 6, Coordinates: (486, 234)
# Landmark ID: 7, Coordinates: (449, 210)
# Landmark ID: 8, Coordinates: (420, 198)
# Landmark ID: 9, Coordinates: (532, 287)
# Landmark ID: 10, Coordinates: (486, 240)
# Landmark ID: 11, Coordinates: (445, 221)
# Landmark ID: 12, Coordinates: (412, 213)
# Landmark ID: 13, Coordinates: (530, 302)
# Landmark ID: 14, Coordinates: (479, 258)
# Landmark ID: 15, Coordinates: (436, 242)
# Landmark ID: 16, Coordinates: (401, 233)
# Landmark ID: 17, Coordinates: (516, 325)
# Landmark ID: 18, Coordinates: (463, 291)
# Landmark ID: 19, Coordinates: (427, 275)
# Landmark ID: 20, Coordinates: (398, 267)
